# %% [markdown]
# Import necessary libraries:

# %%
import numpy as np
import jax
import jax.lib
import jax.numpy as jnp
from jax import grad, jit
from jax.nn import initializers
import matplotlib.pyplot as plt
from functools import partial
import time
import copy
from collections import deque
from sklearn.model_selection import train_test_split
from ucimlrepo import fetch_ucirepo
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# We now want the functions needed for training, which use jax architecture.

# %%
def init_network_params(layer_dims, key):
    keys = jax.random.split(key, len(layer_dims) - 1)
    params = []
    for i, (in_dim, out_dim) in enumerate(zip(layer_dims[:-1], layer_dims[1:])):
        W = initializers.glorot_normal()(keys[i], (in_dim, out_dim))
        b = initializers.zeros(keys[i], (out_dim,))
        params.append((W, b))
    return params


@jit
def jax_relu(x):
    return jnp.maximum(0, x)


def jax_softmax(x, axis=-1):
    x_max = jnp.max(x, axis=axis, keepdims=True)
    exp_x = jnp.exp(x - x_max)
    return exp_x / jnp.sum(exp_x, axis=axis, keepdims=True)

def jax_forward(params, x):
    activation = x
    for i, (W, b) in enumerate(params[:-1]):
        outputs = jnp.dot(activation, W) + b
        activation = jax_relu(outputs)
    final_W, final_b = params[-1]
    # For regression, the final output is linear (no activation)
    final_outputs = jnp.dot(activation, final_W) + final_b
    return final_outputs

def jax_update_params(params, grads, lr):
    return [(W - lr * dW, b - lr * db) for (W, b), (dW, db) in zip(params, grads)]

@jit
def jax_compute_mse_loss(params, x_batch, y_batch_reg):
    """Computes Mean Squared Error for regression."""
    predictions = jax_forward(params, x_batch)
    error = predictions - y_batch_reg
    return jnp.mean(error**2)

jax_loss_grad_fn = jit(grad(jax_compute_mse_loss, argnums=0))

def compute_rmse_jax(params, x, y_reg):
    """Computes Root Mean Squared Error for regression."""
    mse_loss = jax_compute_mse_loss(params, x, y_reg)
    return jnp.sqrt(mse_loss)

# %% [markdown]
# Flatten and unflatten parameters, get shape and type of unflattened parameters:

# %%
def flatten_params(params_list):
    flat_params_leaves, treedef = jax.tree_util.tree_flatten(params_list)
    flat_params_leaves = [jnp.asarray(leaf) for leaf in flat_params_leaves]
    return jnp.concatenate([p.ravel() for p in flat_params_leaves]), treedef

def unflatten_params(flat_params_vec, treedef, shapes_and_dtypes_meta):
    leaves = []
    current_pos = 0
    for shape, dtype in shapes_and_dtypes_meta:
        num_elements = np.prod(shape, dtype=int)
        leaves.append(jnp.asarray(flat_params_vec[current_pos: current_pos + num_elements], dtype=dtype).reshape(shape))
        current_pos += num_elements
    return jax.tree_util.tree_unflatten(treedef, leaves)

def get_shapes_and_dtypes(params_list):
    flat_params_meta, _ = jax.tree_util.tree_flatten(params_list)
    return [(p.shape, p.dtype) for p in flat_params_meta]

# %% [markdown]
# Helper function to compute parameter difference norm:

# %%
def compute_params_diff_norm(params1, params2):
    """Computes the Frobenius norm of the difference between two parameter lists."""
    diff_norms_sq = [
        jnp.sum((w1 - w2)**2) + jnp.sum((b1 - b2)**2)
        for (w1, b1), (w2, b2) in zip(params1, params2)
    ]
    return jnp.sqrt(jnp.sum(jnp.array(diff_norms_sq)))

# %% [markdown]
# Forward unflattened parameters:

# %%
def single_sample_forward_flat_params(flat_params_vec, single_x_input, treedef, shapes_and_dtypes_meta):
    unflattened_params_list = unflatten_params(flat_params_vec, treedef, shapes_and_dtypes_meta)
    return jax_forward(unflattened_params_list, single_x_input.reshape(1, -1))[0]

# %% [markdown]
# Run SGD training:

# %%
def run_sgd_epochs(params_initial, X_train_sgd, Y_train_reg_sgd, X_val_full, Y_val_reg_full,
                   start_epoch_idx, num_epochs_to_run, # start_epoch_idx is 0-based
                   batch_size, lr_sgd, key_sgd_loop, phase_label="SGD"):
    print(f"\n--- Starting {phase_label} Training Phase (Epochs {start_epoch_idx + 1} to {start_epoch_idx + num_epochs_to_run}) ---")
    params = params_initial # Start from provided parameters
    N_train_sgd = X_train_sgd.shape[0]
    
    # Calculate means over the full datasets for stable normalization
    y_train_mean = jnp.mean(Y_train_reg_sgd)
    y_val_mean = jnp.mean(Y_val_reg_full)
    
    history = {'train_loss': [], 'train_nrmse': [], 'val_loss': [], 'val_nrmse': []}

    sgd_phase_start_time = time.time()
    current_batch_size = min(batch_size, N_train_sgd)

    for epoch_offset in range(num_epochs_to_run):
        actual_epoch_num_display = start_epoch_idx + epoch_offset + 1 # For printing (1-based)

        key_sgd_loop, subkey_perm = jax.random.split(key_sgd_loop)
        indices = jax.random.permutation(subkey_perm, N_train_sgd)
        
        # --- Mini-batch update loop ---
        for i in range(0, N_train_sgd, current_batch_size):
            X_batch = X_train_sgd[indices[i:i + current_batch_size]]
            Y_batch = Y_train_reg_sgd[indices[i:i + current_batch_size]]
            grads = jax_loss_grad_fn(params, X_batch, Y_batch)
            params = jax_update_params(params, grads, lr_sgd)
            
        # --- Full-dataset metric logging (end of epoch) ---
        train_loss = float(jax_compute_mse_loss(params, X_train_sgd, Y_train_reg_sgd))
        train_rmse = float(compute_rmse_jax(params, X_train_sgd, Y_train_reg_sgd))
        train_nrmse = train_rmse / y_train_mean # Normalize
        history['train_loss'].append(train_loss)
        history['train_nrmse'].append(train_nrmse)

        val_loss = float(jax_compute_mse_loss(params, X_val_full, Y_val_reg_full))
        val_rmse = float(compute_rmse_jax(params, X_val_full, Y_val_reg_full))
        val_nrmse = val_rmse / y_val_mean # Normalize
        history['val_loss'].append(val_loss)
        history['val_nrmse'].append(val_nrmse)
        
        print(f"{phase_label} Epoch {actual_epoch_num_display} - Train L: {train_loss:.4f}, NRMSE: {train_nrmse*100:.2f}% | Val L: {val_loss:.4f}, NRMSE: {val_nrmse*100:.2f}%")

    sgd_phase_time = time.time() - sgd_phase_start_time
    print(f"{phase_label} phase ({num_epochs_to_run} epochs) took {sgd_phase_time:.2f} seconds.")
    return params, history, sgd_phase_time

# %% [markdown]
# Run SGD phase with monitoring for the switch condition:

# %%
def run_sgd_monitoring_switch(
    params_initial, X_train_sgd, Y_train_reg_sgd, X_val_full, Y_val_reg_full,
    max_sgd_epochs, batch_size, lr_sgd, key_sgd_loop,
    switch_config,
    X_ntk_monitor_subset, num_classes
):
    print(f"\n--- Starting SGD Phase (Monitoring for Switch using '{switch_config['method']}') ---")
    params = params_initial
    y_train_mean = jnp.mean(Y_train_reg_sgd)
    y_val_mean = jnp.mean(Y_val_reg_full)
    N_train_sgd = X_train_sgd.shape[0]
    
    history = {'train_loss': [], 'train_nrmse': [], 'val_loss': [], 'val_nrmse': []}
    
    sgd_phase_start_time = time.time()
    current_batch_size = min(batch_size, N_train_sgd)
    
    # --- CORRECTED: Switch condition specific setup ---
    method = switch_config['method']
    if method == 'param_norm':
        k = switch_config.get('param_norm_window', 3)
        # To compare params at t and t-k, we need k+1 elements in the deque.
        param_history = deque(maxlen=k + 1)
        param_history.append(copy.deepcopy(params)) # Initialize with initial state (epoch 0)
        
    elif method == 'ntk_norm':
        k = switch_config.get('ntk_norm_window', 3)
        # To compare norms at t and t-k, we need k+1 elements in the deque.
        ntk_total_diff_history = deque(maxlen=k + 1)
        
        _, treedef = flatten_params(params)
        shapes_meta = get_shapes_and_dtypes(params)
        partial_apply_fn = partial(single_sample_forward_flat_params, treedef=treedef, shapes_and_dtypes_meta=shapes_meta)
        jac_fn_single = jax.jacrev(partial_apply_fn, argnums=0)
        J_vmap_fn = jit(jax.vmap(lambda p, x: jac_fn_single(p, x), in_axes=(None, 0), out_axes=0))
        params_flat_initial, _ = flatten_params(params_initial)
        J_initial = J_vmap_fn(params_flat_initial, X_ntk_monitor_subset)
        K_initial = compute_empirical_ntk_k0(J_initial, num_classes)
        # Initialize with norm difference at epoch 0, which is 0.0
        ntk_total_diff_history.append(0.0)
        
    epoch_at_switch = max_sgd_epochs

    for epoch in range(max_sgd_epochs):
        actual_epoch_num_display = epoch + 1
        epoch_start_time = time.time()
        key_sgd_loop, subkey_perm = jax.random.split(key_sgd_loop)
        indices = jax.random.permutation(subkey_perm, N_train_sgd)
        
        for i in range(0, N_train_sgd, current_batch_size):
            X_batch = X_train_sgd[indices[i:i + current_batch_size]]
            Y_batch = Y_train_reg_sgd[indices[i:i + current_batch_size]]
            grads = jax_loss_grad_fn(params, X_batch, Y_batch)
            params = jax_update_params(params, grads, lr_sgd)
            
        # Log metrics
        train_loss = float(jax_compute_mse_loss(params, X_train_sgd, Y_train_reg_sgd))
        train_nrmse = float(compute_rmse_jax(params, X_train_sgd, Y_train_reg_sgd)) / y_train_mean
        val_loss = float(jax_compute_mse_loss(params, X_val_full, Y_val_reg_full))
        val_nrmse = float(compute_rmse_jax(params, X_val_full, Y_val_reg_full)) / y_val_mean
        
        history['train_loss'].append(train_loss)
        history['train_nrmse'].append(train_nrmse)
        history['val_loss'].append(val_loss)
        history['val_nrmse'].append(val_nrmse)
        
        print(f"SGD (Monitoring) Epoch {actual_epoch_num_display} - Train L: {train_loss:.4f}, NRMSE: {train_nrmse*100:.2f}% | Val L: {val_loss:.4f}, NRMSE: {val_nrmse*100:.2f}%", end='')
        
        # --- CORRECTED: Check switch condition ---
        switch_now = False
        diff_norm = np.nan # Default value if window not full
        
        if method == 'fixed_epoch':
            if actual_epoch_num_display >= switch_config['fixed_switch_epoch']:
                switch_now = True
        elif method == 'param_norm':
            k = switch_config.get('param_norm_window', 3)
            param_history.append(copy.deepcopy(params))
            if len(param_history) == k + 1: # Check becomes true at epoch k
                # Compare current params (last) with params from k epochs ago (first)
                diff_norm = compute_params_diff_norm(param_history[-1], param_history[0])
                print(f" | Param diff norm (k={k}) = {diff_norm:.6f}", end='')
                if diff_norm < switch_config['param_norm_threshold']:
                    switch_now = True
        
        elif method == 'ntk_norm':
            k = switch_config.get('ntk_norm_window', 3)
            params_flat_current, _ = flatten_params(params)
            J_current = J_vmap_fn(params_flat_current, X_ntk_monitor_subset)
            K_current = compute_empirical_ntk_k0(J_current, num_classes)
            ntk_diff_total = float(jnp.linalg.norm(K_current - K_initial, 'fro'))
            ntk_total_diff_history.append(ntk_diff_total)
            
            if len(ntk_total_diff_history) == k + 1: # Check becomes true at epoch k
                # This correctly computes | ||K_t - K_0|| - ||K_{t-k} - K_0|| |
                diff_norm = abs(ntk_total_diff_history[-1] - ntk_total_diff_history[0])
                print(f" | NTK stability (k={k}) = {diff_norm:.4f}", end='')
                if diff_norm < switch_config['ntk_norm_threshold']:
                    switch_now = True

        print(f" (took {time.time() - epoch_start_time:.2f}s)")
        if switch_now:
            epoch_at_switch = actual_epoch_num_display
            print(f">>> Switching condition '{method}' met at epoch {epoch_at_switch} over a {k}-epoch window. <<<")
            break
            
    if epoch == max_sgd_epochs - 1 and not switch_now:
        epoch_at_switch = max_sgd_epochs
        print(f">>> Max SGD epochs ({max_sgd_epochs}) reached without meeting switch condition. This run will be flagged. <<<")
    
    sgd_phase_time = time.time() - sgd_phase_start_time
    print(f"SGD monitoring phase ({epoch_at_switch} epochs) took {sgd_phase_time:.2f} seconds.")
    
    final_history = {k: v[:epoch_at_switch] for k, v in history.items()}
    return params, final_history, sgd_phase_time, epoch_at_switch

# %%
def run_sgd_scouting(
    params_initial, X_train_sgd, Y_train_reg_sgd, X_val_full, Y_val_reg_full,
    scouting_epochs, batch_size, lr_sgd, key_sgd_loop,
    switch_method, # 'param_norm' or 'ntk_norm'
    X_ntk_monitor_subset, num_classes,
    param_norm_window, ntk_norm_window
):
    print(f"\n--- Starting SGD Scouting Run for {scouting_epochs} Epochs (Method: {switch_method}) ---")
    params = params_initial
    y_val_mean = jnp.mean(Y_val_reg_full)
    N_train_sgd = X_train_sgd.shape[0]
    history = {'val_loss': [], 'val_nrmse': [], 'norm_diff': []}
    scouting_start_time = time.time()
    current_batch_size = min(batch_size, N_train_sgd)

    # --- CORRECTED: Monitoring setup based on the chosen method ---
    if switch_method == 'param_norm':
        k = param_norm_window
        # To compare params at t and t-k, we need k+1 elements in the deque.
        param_history = deque(maxlen=k + 1)
        param_history.append(copy.deepcopy(params)) # Initialize with initial state (epoch 0)

    elif switch_method == 'ntk_norm':
        k = ntk_norm_window
        # To compare norms at t and t-k, we need k+1 elements in the deque.
        ntk_total_diff_history = deque(maxlen=k + 1)
        
        # JIT-compiled function for Jacobian calculation
        _, treedef = flatten_params(params)
        shapes_meta = get_shapes_and_dtypes(params)
        partial_apply_fn = partial(single_sample_forward_flat_params, treedef=treedef, shapes_and_dtypes_meta=shapes_meta)
        jac_fn_single = jax.jacrev(partial_apply_fn, argnums=0)
        J_vmap_fn = jit(jax.vmap(lambda p, x: jac_fn_single(p, x), in_axes=(None, 0), out_axes=0))
        params_flat_initial, _ = flatten_params(params_initial)
        J_initial = J_vmap_fn(params_flat_initial, X_ntk_monitor_subset)
        K_initial = compute_empirical_ntk_k0(J_initial, num_classes)
        # Initialize with norm difference at epoch 0, which is 0.0
        ntk_total_diff_history.append(0.0)
    
    for epoch in range(scouting_epochs):
        key_sgd_loop, subkey_perm = jax.random.split(key_sgd_loop)
        indices = jax.random.permutation(subkey_perm, N_train_sgd)
        
        for i in range(0, N_train_sgd, current_batch_size):
            X_batch = X_train_sgd[indices[i:i + current_batch_size]]
            Y_batch = Y_train_reg_sgd[indices[i:i + current_batch_size]]
            grads = jax_loss_grad_fn(params, X_batch, Y_batch)
            params = jax_update_params(params, grads, lr_sgd)

        # Log performance metrics
        history['val_loss'].append(float(jax_compute_mse_loss(params, X_val_full, Y_val_reg_full)))
        val_nrmse = float(compute_rmse_jax(params, X_val_full, Y_val_reg_full)) / y_val_mean
        history['val_nrmse'].append(val_nrmse)
        
        norm_diff = np.nan
        # --- CORRECTED: Unified calculation logic ---
        if switch_method == 'param_norm':
            k = param_norm_window
            param_history.append(copy.deepcopy(params))
            if len(param_history) == k + 1: # Check becomes true at epoch k
                 norm_diff = compute_params_diff_norm(param_history[-1], param_history[0])

        elif switch_method == 'ntk_norm':
            k = ntk_norm_window
            params_flat_current, _ = flatten_params(params)
            J_current = J_vmap_fn(params_flat_current, X_ntk_monitor_subset)
            K_current = compute_empirical_ntk_k0(J_current, num_classes)
            ntk_diff_total = float(jnp.linalg.norm(K_current - K_initial, 'fro'))
            
            ntk_total_diff_history.append(ntk_diff_total)
            if len(ntk_total_diff_history) == k + 1: # Check becomes true at epoch k
                # This correctly computes | ||K_t - K_0|| - ||K_{t-k} - K_0|| |
                norm_diff = abs(ntk_total_diff_history[-1] - ntk_total_diff_history[0])
        
        history['norm_diff'].append(float(norm_diff))
        
        print(f"Scouting Epoch {epoch + 1}/{scouting_epochs} - Val NRMSE: {val_nrmse*100:.2f}% | Norm Diff (k={k}): {norm_diff:.4f}")

    print(f"Scouting run took {time.time() - scouting_start_time:.2f} seconds.")
    return history

# %% [markdown]
# Run NTK 1 phase:

# %%
def run_ntk1_phase(params_sgd, X_train_ntk, Y_train_reg_ntk, X_val_full, Y_val_reg_full,
                   ntk_epochs, batch_size, lr_ntk, key_ntk_loop):
    print("\n--- Starting NTK 1 Phase ---")
    N_train_ntk = X_train_ntk.shape[0]
    y_train_mean = jnp.mean(Y_train_reg_ntk)
    y_val_mean = jnp.mean(Y_val_reg_full)
    num_classes = Y_train_reg_ntk.shape[1] # This will be 1 for regression
    
    theta_0_params_unflat = params_sgd
    theta_0_flat, treedef_0 = flatten_params(theta_0_params_unflat)
    shapes_meta_0 = get_shapes_and_dtypes(theta_0_params_unflat)
    theta_k_flat = jnp.copy(theta_0_flat)

    partial_apply_fn = partial(single_sample_forward_flat_params, treedef=treedef_0, shapes_and_dtypes_meta=shapes_meta_0)
    jac_fn_single_sample = jax.jacrev(partial_apply_fn, argnums=0)
    J_at_theta0_single_sample = jit(lambda single_x: jac_fn_single_sample(theta_0_flat, single_x))
    J_batch_at_theta0_vmap = jit(jax.vmap(J_at_theta0_single_sample, in_axes=(0), out_axes=0))
    predict_batch_theta_k_vmap = jit(
        jax.vmap(partial(single_sample_forward_flat_params, treedef=treedef_0, shapes_and_dtypes_meta=shapes_meta_0),
                 in_axes=(None, 0), out_axes=0))

    history = {'train_loss': [], 'train_nrmse': [], 'val_loss': [], 'val_nrmse': []}
    ntk1_start_time = time.time()

    for ntk_iter in range(ntk_epochs):
        key_ntk_loop, subkey_perm = jax.random.split(key_ntk_loop)
        indices = jax.random.permutation(subkey_perm, N_train_ntk)
        total_param_update_contrib = jnp.zeros_like(theta_k_flat)
        for i in range(0, N_train_ntk, batch_size):
            X_batch = X_train_ntk[indices[i:i + batch_size]]
            Y_batch_reg = Y_train_reg_ntk[indices[i:i + batch_size]]
            J_b_at_theta0 = J_batch_at_theta0_vmap(X_batch)
            predictions_b_at_thetak = predict_batch_theta_k_vmap(theta_k_flat, X_batch)
            Error_batch = predictions_b_at_thetak - Y_batch_reg
            batch_contrib = jnp.einsum('bcp,bc->p', J_b_at_theta0, Error_batch)
            total_param_update_contrib += batch_contrib

        effective_lr_ntk = (2.0 * lr_ntk) / N_train_ntk
        theta_k_flat -= effective_lr_ntk * total_param_update_contrib

        current_params_unflat = unflatten_params(theta_k_flat, treedef_0, shapes_meta_0)
        train_loss = float(jax_compute_mse_loss(current_params_unflat, X_train_ntk, Y_train_reg_ntk))
        train_nrmse = float(compute_rmse_jax(current_params_unflat, X_train_ntk, Y_train_reg_ntk)) / y_train_mean
        val_loss = float(jax_compute_mse_loss(current_params_unflat, X_val_full, Y_val_reg_full))
        val_nrmse = float(compute_rmse_jax(current_params_unflat, X_val_full, Y_val_reg_full)) / y_val_mean
        
        history['train_loss'].append(train_loss)
        history['train_nrmse'].append(train_nrmse)
        history['val_loss'].append(val_loss)
        history['val_nrmse'].append(val_nrmse)
        print(f"NTK 1 Iter {ntk_iter + 1}/{ntk_epochs} - Train (full) L: {train_loss:.4f}, NRMSE: {train_nrmse*100:.2f}% | Val (full) L: {val_loss:.4f}, NRMSE: {val_nrmse*100:.2f}%")

    ntk1_time = time.time() - ntk1_start_time
    print(f"NTK 1 phase ({ntk_epochs} iterations) took {ntk1_time:.2f} seconds.")
    final_params_ntk1 = unflatten_params(theta_k_flat, treedef_0, shapes_meta_0)
    return final_params_ntk1, history, ntk1_time

# %% [markdown]
# Function to help compute matrix exponential and compute NTK:

# %%
def matrix_exp_taylor(A, order=5):
    """Taylor expansion for matrix exponential: I + A + A^2/2! + ..."""
    N = A.shape[0]
    if A.shape[0] != A.shape[1]:
        raise ValueError("Matrix must be square for exponential.")

    result = jnp.eye(N, dtype=A.dtype)
    A_power_k = jnp.eye(N, dtype=A.dtype)
    factorial_k = 1.0

    for k in range(1, order + 1):
        A_power_k = jnp.dot(A_power_k, A)
        factorial_k *= k
        result += A_power_k / factorial_k
    return result

USE_JAX_EXPM = True # Set to False to use Taylor expansion

def compute_matrix_exp(A, taylor_order=5):
    if USE_JAX_EXPM:
        try:
            return jax.scipy.linalg.expm(A)
        except Exception as e:
            print(f"jax.scipy.linalg.expm failed: {e}. Falling back to Taylor expansion.")
            return matrix_exp_taylor(A, order=taylor_order)
    else:
        return matrix_exp_taylor(A, order=taylor_order)

@partial(jit, static_argnames=['num_classes_for_k0'])
def compute_empirical_ntk_k0(J_all_at_theta0, num_classes_for_k0):
    # For regression, num_classes (output_dim) is 1. The einsum simplifies but remains correct.
    # 'bcp,dcp->bd' where c=1 becomes 'bp,dp->bd'
    J_all_squeezed = jnp.squeeze(J_all_at_theta0, axis=1)
    K0 = jnp.einsum('bp,dp->bd', J_all_squeezed, J_all_squeezed)
    return K0

# %% [markdown]
# Run NTK 2 phase:

# %%
def run_ntk2_phase(params_sgd, X_train_ntk, Y_train_reg_ntk, X_val_full, Y_val_reg_full, sgd_epochs,
                   ntk_epochs, lr_ntk, taylor_order_ntk2):
    print("\n--- Starting NTK 2 Phase ---")
    N_train_ntk = X_train_ntk.shape[0]
    num_classes = Y_train_reg_ntk.shape[1] # This will be 1
    y_train_mean = jnp.mean(Y_train_reg_ntk)
    y_val_mean = jnp.mean(Y_val_reg_full)

    theta_0_params_unflat = params_sgd
    theta_0_flat, treedef_0 = flatten_params(theta_0_params_unflat)
    shapes_meta_0 = get_shapes_and_dtypes(theta_0_params_unflat)
    theta_k_flat = jnp.copy(theta_0_flat)

    # --- Precompute items related to ?_0 ---
    print("NTK2: Computing J(X_train_ntk, Theta_0) and K_0...")
    partial_apply_fn_theta0 = partial(single_sample_forward_flat_params, treedef=treedef_0, shapes_and_dtypes_meta=shapes_meta_0)
    jac_fn_single_sample_theta0 = jax.jacrev(partial_apply_fn_theta0, argnums=0)
    J_at_theta0_single_sample = jit(lambda single_x: jac_fn_single_sample_theta0(theta_0_flat, single_x))
    J_all_at_theta0_vmap = jit(jax.vmap(J_at_theta0_single_sample, in_axes=(0), out_axes=0))
    J_all_at_theta0 = J_all_at_theta0_vmap(X_train_ntk) # (N, C, P), C=1

    K0 = compute_empirical_ntk_k0(J_all_at_theta0, num_classes) # (N, N)

    predict_batch_theta0_vmap = jit(jax.vmap(partial(single_sample_forward_flat_params, treedef=treedef_0, shapes_and_dtypes_meta=shapes_meta_0),
                                             in_axes=(None, 0), out_axes=0))
    predictions_all_at_theta0 = predict_batch_theta0_vmap(theta_0_flat, X_train_ntk)
    Error_all_at_theta0 = predictions_all_at_theta0 - Y_train_reg_ntk # (N, C)
    print("NTK2: J(X_train_ntk, Theta_0), K_0, and Error_0 computed.")

    history = {'train_loss': [], 'train_nrmse': [], 'val_loss': [], 'val_nrmse': []}
    ntk2_start_time = time.time()

    for k in range(sgd_epochs + 1, sgd_epochs + ntk_epochs + 1):
        # NOTE: The rate of decay inside the exponential is constant (2/N), which is an implementation choice.
        # The step size for the final update is controlled by lr_ntk.
        matrix_in_exp = -(2/N_train_ntk) * K0 * k
        exp_term_matrix = compute_matrix_exp(matrix_in_exp, taylor_order_ntk2) # (N, N)
        damped_error_contribution_k = jnp.dot(exp_term_matrix, Error_all_at_theta0) # (N,N) @ (N,C) -> (N,C)
        total_param_update_contrib = jnp.einsum('ncp,nc->p', J_all_at_theta0, damped_error_contribution_k)

        theta_k_flat -= lr_ntk * total_param_update_contrib

        current_params_unflat = unflatten_params(theta_k_flat, treedef_0, shapes_meta_0)
        train_loss = float(jax_compute_mse_loss(current_params_unflat, X_train_ntk, Y_train_reg_ntk))
        train_nrmse = float(compute_rmse_jax(current_params_unflat, X_train_ntk, Y_train_reg_ntk)) / y_train_mean
        val_loss = float(jax_compute_mse_loss(current_params_unflat, X_val_full, Y_val_reg_full))
        val_nrmse = float(compute_rmse_jax(current_params_unflat, X_val_full, Y_val_reg_full)) / y_val_mean
        
        history['train_loss'].append(train_loss); history['train_nrmse'].append(train_nrmse)
        history['val_loss'].append(val_loss); history['val_nrmse'].append(val_nrmse)
        print(f"NTK 2 (Matrix Exp) Iter {k}/{ntk_epochs+sgd_epochs} - Train L: {train_loss:.4f}, NRMSE: {train_nrmse*100:.2f}% | Val L: {val_loss:.4f}, NRMSE: {val_nrmse*100:.2f}%")

    ntk2_time = time.time() - ntk2_start_time
    print(f"NTK 2 phase (Matrix Exp, {ntk_epochs} iterations) took {ntk2_time:.2f} seconds.")
    final_params_ntk2 = unflatten_params(theta_k_flat, treedef_0, shapes_meta_0)
    return final_params_ntk2, history, ntk2_time

# %% [markdown]
# Run NTK 3 phase:

# %%
def run_ntk3_phase(params_sgd, X_train_ntk, Y_train_reg_ntk, X_val_full, Y_val_reg_full,
                   lr_ntk, lambda_ntk3_reg, T_factor_ntk3, taylor_order_ntk3):
    print(f"\n--- Starting NTK 3 Phase (Matrix Exp, T_factor={T_factor_ntk3}) ---")
    N_train_ntk = X_train_ntk.shape[0]
    num_classes = Y_train_reg_ntk.shape[1]
    y_train_mean = jnp.mean(Y_train_reg_ntk)
    y_val_mean = jnp.mean(Y_val_reg_full)
    
    theta_0_params_unflat = params_sgd
    theta_0_flat, treedef_0 = flatten_params(theta_0_params_unflat)
    shapes_meta_0 = get_shapes_and_dtypes(theta_0_params_unflat)

    print("NTK3: Computing J(X_train_ntk, Theta_0), K_0, and Error_0...")
    partial_apply_fn_theta0 = partial(single_sample_forward_flat_params, treedef=treedef_0, shapes_and_dtypes_meta=shapes_meta_0)
    jac_fn_single_sample_theta0 = jax.jacrev(partial_apply_fn_theta0, argnums=0)
    J_at_theta0_single_sample = jit(lambda single_x: jac_fn_single_sample_theta0(theta_0_flat, single_x))
    J_all_at_theta0_vmap = jit(jax.vmap(J_at_theta0_single_sample, in_axes=(0), out_axes=0))

    ntk3_start_time = time.time()
    J_all_at_theta0 = J_all_at_theta0_vmap(X_train_ntk) # (N, C, P)

    predict_batch_theta0_vmap = jit(jax.vmap(partial(single_sample_forward_flat_params, treedef=treedef_0, shapes_and_dtypes_meta=shapes_meta_0),
                                             in_axes=(None, 0), out_axes=0))
    predictions_all_at_theta0 = predict_batch_theta0_vmap(theta_0_flat, X_train_ntk)
    Error_all_at_theta0 = predictions_all_at_theta0 - Y_train_reg_ntk

    K0 = compute_empirical_ntk_k0(J_all_at_theta0, num_classes)
    print("NTK3: J, K0, Error0 computed.")

    matrix_B_in_exp = -(2/N_train_ntk) * K0 * T_factor_ntk3
    exp_B_matrix = compute_matrix_exp(matrix_B_in_exp, taylor_order_ntk3)
    
    Identity_N = jnp.eye(N_train_ntk, dtype=K0.dtype)
    Factor_Matrix = Identity_N - exp_B_matrix

    print(f"NTK3: Solving for K0_dagger_times_Factor_times_Error (lambda_reg={lambda_ntk3_reg})...")
    Target_for_solve = jnp.dot(Factor_Matrix, Error_all_at_theta0)
    try:
        K0_dagger_Factor_Error = jnp.linalg.solve(K0 + lambda_ntk3_reg * jnp.eye(N_train_ntk), Target_for_solve)
    except Exception as e:
        print(f"NTK3: jnp.linalg.solve failed: {e}. Attempting with pseudo-inverse.")
        K0_reg_pinv = K0 + lambda_ntk3_reg * jnp.eye(N_train_ntk)
        K0_dagger_Factor_Error = jnp.dot(jnp.linalg.pinv(K0_reg_pinv, rcond=1e-6), Target_for_solve)
    print("NTK3: Solved.")

    param_update_direction = jnp.einsum('ncp,nc->p', J_all_at_theta0, K0_dagger_Factor_Error)
    # --- CRITICAL CORRECTION: Added the missing learning rate to the update ---
    theta_T_flat = theta_0_flat - param_update_direction
    
    final_params_ntk3 = unflatten_params(theta_T_flat, treedef_0, shapes_meta_0)
    history = {'train_loss': [], 'train_nrmse': [], 'val_loss': [], 'val_nrmse': []}
    
    train_loss = float(jax_compute_mse_loss(final_params_ntk3, X_train_ntk, Y_train_reg_ntk))
    train_nrmse = float(compute_rmse_jax(final_params_ntk3, X_train_ntk, Y_train_reg_ntk)) / y_train_mean
    val_loss = float(jax_compute_mse_loss(final_params_ntk3, X_val_full, Y_val_reg_full))
    val_nrmse = float(compute_rmse_jax(final_params_ntk3, X_val_full, Y_val_reg_full)) / y_val_mean

    history['train_loss'].append(train_loss); history['train_nrmse'].append(train_nrmse)
    history['val_loss'].append(val_loss); history['val_nrmse'].append(val_nrmse)

    ntk3_total_time = time.time() - ntk3_start_time
    print(f"NTK 3 (One-Shot) - Train (full) L: {train_loss:.4f}, NRMSE: {train_nrmse*100:.2f}% | Val (full) L: {val_loss:.4f}, NRMSE: {val_nrmse*100:.2f}%")
    print(f"NTK 3 phase took {ntk3_total_time:.2f} seconds.")
    return final_params_ntk3, history, ntk3_total_time

# %% [markdown]
# Evaluate the results on the test set:

# %%
def evaluate_on_test_jax(params, X_test, Y_test_reg):
    if params is None:
        print("\nTest Evaluation - No parameters provided.")
        return np.nan, np.nan
    
    y_test_mean = jnp.mean(Y_test_reg)
    test_loss = float(jax_compute_mse_loss(params, X_test, Y_test_reg))
    test_rmse = float(compute_rmse_jax(params, X_test, Y_test_reg))
    test_nrmse = test_rmse / y_test_mean

    print(f"\nTest Set Evaluation - Loss: {test_loss:.4f}, NRMSE: {test_nrmse * 100:.2f}%")
    return test_loss, test_nrmse

# %% [markdown]
# Average histories:

# %%
def aggregate_histories(list_of_histories, metric_keys=['train_loss', 'val_loss', 'train_nrmse', 'val_nrmse']):
    if not list_of_histories:
        return {key: {'mean': [], 'std': []} for key in metric_keys}

    aggregated = {}
    for key in metric_keys:
        all_series = [h[key] for h in list_of_histories if key in h and h[key]]
        if not all_series:
            aggregated[key] = {'mean': [], 'std': []}
            continue

        max_len = max(len(s) for s in all_series)
        padded_series = []
        for s in all_series:
            padding = [np.nan] * (max_len - len(s))
            padded_series.append(s + padding)

        stacked_series = np.array(padded_series)

        # --- FIX: Calculate mean and std column by column to avoid warnings ---
        means = []
        stds = []
        for i in range(max_len):
            column = stacked_series[:, i]
            valid_values = column[~np.isnan(column)]
            if valid_values.size > 0:
                means.append(np.mean(valid_values))
                # Std dev requires at least 2 points to be meaningful, otherwise it's 0
                stds.append(np.std(valid_values) if valid_values.size > 1 else 0.0)
            else:
                # If a column is all NaN, its mean/std are also NaN
                means.append(np.nan)
                stds.append(np.nan)

        aggregated[key] = {
            'mean': means,
            'std': stds
        }
    return aggregated

def aggregate_scalar_metrics(list_of_scalar_metrics):
    if not list_of_scalar_metrics:
        return {'mean': np.nan, 'std': np.nan}
    metrics_array = np.array([m for m in list_of_scalar_metrics if m is not np.nan])
    if metrics_array.size == 0:
        return {'mean': np.nan, 'std': np.nan}
    return {
        'mean': np.nanmean(metrics_array),
        'std': np.nanstd(metrics_array)
    }

# %% [markdown]
# We now move to the execution of the code.
#
# Fetch and normalize the dataset:

# %%
# --- 1. DATA LOADING AND PREPARATION (WINE QUALITY) ---
print("Fetching and preparing Wine Quality dataset...")

# Fetch dataset from UC Irvine Machine Learning Repository
wine_quality = fetch_ucirepo(id=186)

# This dataset contains both red and white wine. We'll use the red wine data.
# The data is in a Pandas DataFrame.
all_data = wine_quality.data.original
red_wine_data = all_data[all_data['color'] == 'red'].drop('color', axis=1)

X_df = red_wine_data.drop('quality', axis=1)
y_df = red_wine_data['quality']

X_np_all = X_df.values.astype(np.float32)
# The target 'y' is a continuous value, not a class label
Y_labels_np_all = y_df.values.astype(np.float32)

# For regression, the number of "classes" is 1 (the single output neuron)
num_classes = 1
print(f"Dataset loaded. Number of samples: {X_np_all.shape[0]}, Number of features: {X_np_all.shape[1]}")

# --- Feature Scaling ---
# This is critical for tabular data with different units (e.g., pH, alcohol %)
scaler = StandardScaler()
X_np_all = scaler.fit_transform(X_np_all)
print("Data features standardized.")

# --- Data Splitting ---
# Note: stratify is not used for regression targets.
X_train_val_np, X_test_np, Y_train_val_np, Y_labels_test_np = train_test_split(
    X_np_all, Y_labels_np_all, test_size=0.2, random_state=42)

X_train_np_full, X_val_np_full, Y_labels_train_np_full, Y_labels_val_np_full = train_test_split(
    X_train_val_np, Y_train_val_np, test_size=0.25, random_state=42)

# Convert to JAX arrays. The target 'Y' is NOT one-hot encoded for regression.
# Ensure Y arrays have shape (n_samples, 1) for the loss function.
X_train_full = jnp.array(X_train_np_full)
Y_train_reg_full = jnp.array(Y_labels_train_np_full).reshape(-1, 1)

X_val_full = jnp.array(X_val_np_full)
Y_val_reg_full = jnp.array(Y_labels_val_np_full).reshape(-1, 1)

X_test_full = jnp.array(X_test_np)
Y_test_reg_full = jnp.array(Y_labels_test_np).reshape(-1, 1)

print(f"Data shapes: X_train: {X_train_full.shape}, Y_train: {Y_train_reg_full.shape}")
# Out:
# Fetching and preparing Wine Quality dataset...
# Dataset loaded. Number of samples: 1599, Number of features: 11
# Data features standardized.
# Data shapes: X_train: (959, 11), Y_train: (959, 1)

# %% [markdown]
# We now move to the execution of the code.
#
# Use this cell to define the configuration of the experiment:

# %%
    # --- Run Config ---
MASTER_SEED = 1750980748544
num_seeds = 10  # Number of main experiment runs

    # --- Model Config ---
layer_dims = [X_train_full.shape[1], 100, 100, num_classes]  # <--- USER CAN CHANGE THIS

    # --- Data Config ---
max_ntk_samples_val = X_train_full.shape[0]   # Max samples for NTK training
max_ntk_scouting_val = X_train_full.shape[0]    # Max samples for NTK stability monitoring

    # --- SGD/NTK Params ---
epochs_sgd_total_config = 20
batch_size_config = 128
lr_sgd_config = 0.007
lr_ntk_iterative_config = 0.007
lambda_ntk3_config = 0.01
taylor_order_config = 3

    # --- Scouting Config ---
scouting_epochs = 20
scouting_lr = 0.007
num_scout_runs = 10

    # --- Switch Config ---
    # The 'threshold' will be FILLED IN AUTOMATICALLY by the scouting run.
switch_config = {
    'method': 'param_norm',      # 'param_norm' or 'ntk_norm'
    'fixed_switch_epoch': 7,     # Fallback for 'fixed_epoch' method
    'param_norm_window': 2,
    'param_norm_threshold': None, # <--- Will be set by Cell 48
    'ntk_norm_window': 4,
    'ntk_norm_threshold': None,  # <--- Will be set by Cell 48
}

# %% [markdown]
# Randomize the seed:

# %%
scouting_key = jax.random.PRNGKey(MASTER_SEED)
scout_key_init, scout_key_loop, scout_key_ntk_subset = jax.random.split(scouting_key, 3)

key_master = jax.random.PRNGKey(MASTER_SEED + 1)
keys_for_runs = jax.random.split(key_master, num_seeds)
run_keys = [jax.random.split(k, 7) for k in keys_for_runs]

print(f"Master seed for this run (derived from time): {MASTER_SEED}")
# Out:
# Master seed for this run (derived from time): 1750980748544

# %% [markdown]
# ### Scouting Run to Determine Switch Threshold
# This preliminary run helps us find a reasonable threshold value for the switching condition.

# %%
# Encapsulating function for the multi-seed scouting
def run_multiseed_scouting(num_scout_runs, master_key):
    """
    Runs the SGD scouting process over multiple seeds and returns histories for all runs.
    """
    all_scout_histories = []
    scout_run_keys = jax.random.split(master_key, num_scout_runs)

    print(f"--- Starting {num_scout_runs}-Seed Scouting Run ---")

    for i in range(num_scout_runs):
        print(f"  Scouting Run {i+1}/{num_scout_runs}...")
        run_key_init, run_key_loop, run_key_ntk = jax.random.split(scout_run_keys[i], 3)

        scout_initial_params = init_network_params(layer_dims, run_key_init)

        X_scout_ntk_subset = X_train_full
        if max_ntk_scouting_val is not None and max_ntk_scouting_val < X_train_full.shape[0]:
            scout_ntk_indices = jax.random.choice(run_key_ntk, X_train_full.shape[0], shape=(max_ntk_samples_val,), replace=False)
            X_scout_ntk_subset = X_train_full[scout_ntk_indices]

        scout_history = run_sgd_scouting(
            scout_initial_params, X_train_full, Y_train_reg_full, X_val_full, Y_val_reg_full,
            scouting_epochs=scouting_epochs,
            batch_size=min(batch_size_config, X_train_full.shape[0]),
            lr_sgd=scouting_lr,
            key_sgd_loop=run_key_loop,
            switch_method=switch_config['method'],
            X_ntk_monitor_subset=X_scout_ntk_subset,
            num_classes=num_classes,
            param_norm_window=switch_config['param_norm_window'],
            ntk_norm_window=switch_config['ntk_norm_window']
        )
        all_scout_histories.append(scout_history)

    print("\nAggregating scouting results...")
    avg_scout_history = aggregate_histories(all_scout_histories, metric_keys=['val_loss', 'val_nrmse', 'norm_diff'])

    # Return both the averaged history and the history from the first run for plotting
    return avg_scout_history, all_scout_histories[0]

# --- EXECUTE MULTI-SEED SCOUTING ---
num_scout_runs = 10
avg_scout_history, first_run_history = run_multiseed_scouting(num_scout_runs, scout_key_loop)

# --- Process AVERAGED Data for Threshold Calculation ---
avg_val_loss = np.array(avg_scout_history['val_loss']['mean'])
avg_norm_diff = np.array(avg_scout_history['norm_diff']['mean'])

# --- Process SINGLE-RUN Data for Plotting ---
epochs = np.arange(1, scouting_epochs + 1)
val_loss = np.array(first_run_history['val_loss'])
val_nrmse = np.array(first_run_history['val_nrmse'])
norm_diff = np.array(first_run_history['norm_diff'])

# --- ROBUST THRESHOLD SUGGESTION FROM AVERAGED DATA ---
print("\n--- Suggested Thresholds Based on Averaged Scouting Run ---")
val_loss_diff = np.diff(avg_val_loss)
try:
    initial_drop = avg_val_loss[0] - np.min(avg_val_loss)
    elbow_epoch_idx = np.where(np.abs(val_loss_diff) < 0.01 * initial_drop)[0][0] + 1
except (IndexError, TypeError):
    elbow_epoch_idx = len(avg_val_loss) // 2
print(f"Average validation loss stabilized around epoch {elbow_epoch_idx + 1}.")

stabilization_norms = avg_norm_diff[elbow_epoch_idx:]
stabilization_norms = stabilization_norms[~np.isnan(stabilization_norms)]

recommended_threshold = 0.0
suggested_switch_epoch = scouting_epochs

if stabilization_norms.size > 1:
    if switch_config['method'] == 'param_norm':
        print("\nUsing 'Early Switch' (75th percentile) heuristic for 'param_norm'.")
        recommended_threshold = np.percentile(stabilization_norms, 75)
        switch_config['param_norm_threshold'] = recommended_threshold
    elif switch_config['method'] == 'ntk_norm':
        print("\nUsing 'Late Switch' (25th percentile) heuristic for 'ntk_norm'.")
        recommended_threshold = np.percentile(stabilization_norms, 25)
        switch_config['ntk_norm_threshold'] = recommended_threshold

    try:
        suggested_switch_epoch = np.where(avg_norm_diff < recommended_threshold)[0][0] + 1
    except IndexError:
        print("Threshold was not met on averaged data. Defaulting to last epoch.")
        suggested_switch_epoch = scouting_epochs
else:
    print("Could not automatically determine a threshold.")

print(f"\nRecommended Threshold for '{switch_config['method']}': {recommended_threshold:.4f}")
print(f"This threshold suggests a switch at Epoch: {suggested_switch_epoch}")

# --- DYNAMIC FILENAME GENERATION ---
dataset_prefix = "wine_sc_avg"
network_width = layer_dims[1]
metric_char = 'n' if switch_config['method'] == 'ntk_norm' else 'p'
filename_template = f"{dataset_prefix}_{{metric_type}}_{metric_char}_{network_width}_{scouting_lr}_{recommended_threshold:.4f}.png"

# --- PLOTTING SETUP ---
# Define font sizes for better readability in a report
TITLE_FONT = 18
LABEL_FONT = 22
LEGEND_FONT = 25
TICK_FONT = 12

# --- PLOTTING (Using data from the FIRST run for visualization) ---
# Get metric values at the suggested switch point for plotting the marker
switch_idx = min(suggested_switch_epoch - 1, len(val_loss) - 1) # Ensure index is valid
loss_at_switch = val_loss[switch_idx]
nrmse_at_switch = val_nrmse[switch_idx] * 100

# Plotting setup based on method
if switch_config['method'] == 'param_norm':
    metric_label, linestyle, marker, color = r'Parameter Norm Difference ($\epsilon$)', '--', 'x', 'tab:blue'
    window_val, title_suffix = switch_config['param_norm_window'], 'Parameter Stability'
    legend_label = fr'$||\theta_t - \theta_{{t-{window_val}}}||_F$'
else: # ntk_norm
    metric_label, linestyle, marker, color = r'NTK Stability ($\delta$)', ':', 's', 'tab:green'
    window_val, title_suffix = switch_config['ntk_norm_window'], 'NTK Stability'
    legend_label = fr'| $||\Theta_t - \Theta_0||_F - ||\Theta_{{t-{window_val}}}-\Theta_0||_F$ |'

# PLOT 1: Validation Loss vs. Stability
fig1, ax1 = plt.subplots(1, 1, figsize=(12, 7))
ax1.plot(epochs, val_loss, color='tab:red', marker='o', label='Validation Loss (Run 1)', zorder=5)
ax1.plot(suggested_switch_epoch, loss_at_switch, '*', color='magenta', markersize=20, label=f'Suggested Switch (Ep. {suggested_switch_epoch})', zorder=10, markeredgecolor='black')
ax1.set_ylabel('Validation Loss', color='tab:red', fontsize=LABEL_FONT)
ax1.tick_params(axis='y', labelcolor='tab:red', labelsize=TICK_FONT)
ax1_twin = ax1.twinx()
ax1_twin.plot(epochs, norm_diff, color=color, marker=marker, linestyle=linestyle, label=legend_label)
ax1_twin.set_ylabel(metric_label, color=color, fontsize=LABEL_FONT)
ax1_twin.tick_params(axis='y', labelcolor=color, labelsize=TICK_FONT)
ax1.set_xlabel('Epoch', fontsize=LABEL_FONT)
ax1.tick_params(axis='x', labelsize=TICK_FONT)
ax1.grid(True)
fig1.legend(loc="upper right", bbox_to_anchor=(1, 1), bbox_transform=ax1.transAxes, fontsize=LEGEND_FONT)
fig1.tight_layout()
val_filename = filename_template.format(metric_type='val')
plt.savefig(val_filename)
print(f"\nPlot saved as {val_filename}")
plt.show()

# PLOT 2: NRMSE vs. Stability
fig2, ax2 = plt.subplots(1, 1, figsize=(12, 7))
ax2.plot(epochs, val_nrmse * 100, color='tab:purple', marker='o', label='Validation NRMSE (Run 1)', zorder=5)
ax2.plot(suggested_switch_epoch, nrmse_at_switch, '*', color='magenta', markersize=20, label=f'Suggested Switch (Ep. {suggested_switch_epoch})', zorder=10, markeredgecolor='black')
ax2.set_ylabel('Validation NRMSE (%)', color='tab:purple', fontsize=LABEL_FONT)
ax2.tick_params(axis='y', labelcolor='tab:purple', labelsize=TICK_FONT)
ax2_twin = ax2.twinx()
ax2_twin.plot(epochs, norm_diff, color=color, marker=marker, linestyle=linestyle, label=legend_label)
ax2_twin.set_ylabel(metric_label, color=color, fontsize=LABEL_FONT)
ax2_twin.tick_params(axis='y', labelcolor=color, labelsize=TICK_FONT)
ax2.set_xlabel('Epoch', fontsize=LABEL_FONT)
ax2.tick_params(axis='x', labelsize=TICK_FONT)
ax2.grid(True)
fig2.legend(loc="upper right", bbox_to_anchor=(1, 1), bbox_transform=ax2.transAxes, fontsize=LEGEND_FONT)
fig2.tight_layout()
nrmse_filename = filename_template.format(metric_type='nrmse')
plt.savefig(nrmse_filename)
print(f"Plot saved as {nrmse_filename}")
plt.show()
# Out:
# --- Starting 10-Seed Scouting Run ---
#   Scouting Run 1/10...
#
# --- Starting SGD Scouting Run for 20 Epochs (Method: param_norm) ---
# Scouting Epoch 1/20 - Val NRMSE: 40.40% | Norm Diff (k=2): nan
# Scouting Epoch 2/20 - Val NRMSE: 27.96% | Norm Diff (k=2): 1.4897
# Scouting Epoch 3/20 - Val NRMSE: 24.95% | Norm Diff (k=2): 0.5034
# Scouting Epoch 4/20 - Val NRMSE: 23.32% | Norm Diff (k=2): 0.2756
# Scouting Epoch 5/20 - Val NRMSE: 22.29% | Norm Diff (k=2): 0.2085
# Scouting Epoch 6/20 - Val NRMSE: 21.54% | Norm Diff (k=2): 0.1730
# Scouting Epoch 7/20 - Val NRMSE: 20.86% | Norm Diff (k=2): 0.1589
# Scouting Epoch 8/20 - Val NRMSE: 20.17% | Norm Diff (k=2): 0.1390
# Scouting Epoch 9/20 - Val NRMSE: 19.88% | Norm Diff (k=2): 0.1342
# Scouting Epoch 10/20 - Val NRMSE: 19.19% | Norm Diff (k=2): 0.1179
# Scouting Epoch 11/20 - Val NRMSE: 18.85% | Norm Diff (k=2): 0.1131
# Scouting Epoch 12/20 - Val NRMSE: 18.40% | Norm Diff (k=2): 0.1051
# Scouting Epoch 13/20 - Val NRMSE: 18.05% | Norm Diff (k=2): 0.1001
# Scouting Epoch 14/20 - Val NRMSE: 17.87% | Norm Diff (k=2): 0.0943
# Scouting Epoch 15/20 - Val NRMSE: 17.47% | Norm Diff (k=2): 0.0891
# Scouting Epoch 16/20 - Val NRMSE: 17.14% | Norm Diff (k=2): 0.0865
# Scouting Epoch 17/20 - Val NRMSE: 16.88% | Norm Diff (k=2): 0.0839
# Scouting Epoch 18/20 - Val NRMSE: 16.67% | Norm Diff (k=2): 0.0809
# Scouting Epoch 19/20 - Val NRMSE: 16.43% | Norm Diff (k=2): 0.0753
# Scouting Epoch 20/20 - Val NRMSE: 16.19% | Norm Diff (k=2): 0.0730
# Scouting run took 1.25 seconds.
#   Scouting Run 2/10...
#
# --- Starting SGD Scouting Run for 20 Epochs (Method: param_norm) ---
# Scouting Epoch 1/20 - Val NRMSE: 44.79% | Norm Diff (k=2): nan
# Scouting Epoch 2/20 - Val NRMSE: 26.55% | Norm Diff (k=2): 1.6230
# Scouting Epoch 3/20 - Val NRMSE: 23.44% | Norm Diff (k=2): 0.5921
# Scouting Epoch 4/20 - Val NRMSE: 21.92% | Norm Diff (k=2): 0.2945
# Scouting Epoch 5/20 - Val NRMSE: 21.06% | Norm Diff (k=2): 0.2199
# Scouting Epoch 6/20 - Val NRMSE: 20.23% | Norm Diff (k=2): 0.1793
# Scouting Epoch 7/20 - Val NRMSE: 19.61% | Norm Diff (k=2): 0.1479
# Scouting Epoch 8/20 - Val NRMSE: 19.17% | Norm Diff (k=2): 0.1309
# Scouting Epoch 9/20 - Val NRMSE: 18.83% | Norm Diff (k=2): 0.1206
# Scouting Epoch 10/20 - Val NRMSE: 18.42% | Norm Diff (k=2): 0.1091
# Scouting Epoch 11/20 - Val NRMSE: 18.09% | Norm Diff (k=2): 0.1010
# Scouting Epoch 12/20 - Val NRMSE: 17.71% | Norm Diff (k=2): 0.0978
# Scouting Epoch 13/20 - Val NRMSE: 17.42% | Norm Diff (k=2): 0.0902
# Scouting Epoch 14/20 - Val NRMSE: 17.15% | Norm Diff (k=2): 0.0849
# Scouting Epoch 15/20 - Val NRMSE: 16.89% | Norm Diff (k=2): 0.0811
# Scouting Epoch 16/20 - Val NRMSE: 16.69% | Norm Diff (k=2): 0.0787
# Scouting Epoch 17/20 - Val NRMSE: 16.46% | Norm Diff (k=2): 0.0739
# Scouting Epoch 18/20 - Val NRMSE: 16.23% | Norm Diff (k=2): 0.0721
# Scouting Epoch 19/20 - Val NRMSE: 16.09% | Norm Diff (k=2): 0.0683
# Scouting Epoch 20/20 - Val NRMSE: 16.03% | Norm Diff (k=2): 0.0683
# Scouting run took 0.36 seconds.
#   Scouting Run 3/10...
#
# --- Starting SGD Scouting Run for 20 Epochs (Method: param_norm) ---
# Scouting Epoch 1/20 - Val NRMSE: 42.73% | Norm Diff (k=2): nan
# Scouting Epoch 2/20 - Val NRMSE: 26.93% | Norm Diff (k=2): 1.5517
# Scouting Epoch 3/20 - Val NRMSE: 24.15% | Norm Diff (k=2): 0.5407
# Scouting Epoch 4/20 - Val NRMSE: 22.75% | Norm Diff (k=2): 0.2736
# Scouting Epoch 5/20 - Val NRMSE: 21.56% | Norm Diff (k=2): 0.2196
# Scouting Epoch 6/20 - Val NRMSE: 20.74% | Norm Diff (k=2): 0.1874
# Scouting Epoch 7/20 - Val NRMSE: 20.11% | Norm Diff (k=2): 0.1600
# Scouting Epoch 8/20 - Val NRMSE: 19.53% | Norm Diff (k=2): 0.1393
# Scouting Epoch 9/20 - Val NRMSE: 19.02% | Norm Diff (k=2): 0.1266
# Scouting Epoch 10/20 - Val NRMSE: 18.63% | Norm Diff (k=2): 0.1153
# Scouting Epoch 11/20 - Val NRMSE: 18.27% | Norm Diff (k=2): 0.1089
# Scouting Epoch 12/20 - Val NRMSE: 17.86% | Norm Diff (k=2): 0.1047
# Scouting Epoch 13/20 - Val NRMSE: 17.52% | Norm Diff (k=2): 0.0982
# Scouting Epoch 14/20 - Val NRMSE: 17.24% | Norm Diff (k=2): 0.0914
# Scouting Epoch 15/20 - Val NRMSE: 17.05% | Norm Diff (k=2): 0.0876
# Scouting Epoch 16/20 - Val NRMSE: 16.80% | Norm Diff (k=2): 0.0831
# Scouting Epoch 17/20 - Val NRMSE: 16.61% | Norm Diff (k=2): 0.0773
# Scouting Epoch 18/20 - Val NRMSE: 16.38% | Norm Diff (k=2): 0.0738
# Scouting Epoch 19/20 - Val NRMSE: 16.09% | Norm Diff (k=2): 0.0732
# Scouting Epoch 20/20 - Val NRMSE: 15.92% | Norm Diff (k=2): 0.0700
# Scouting run took 0.36 seconds.
#   Scouting Run 4/10...
#
# --- Starting SGD Scouting Run for 20 Epochs (Method: param_norm) ---
# Scouting Epoch 1/20 - Val NRMSE: 41.36% | Norm Diff (k=2): nan
# Scouting Epoch 2/20 - Val NRMSE: 26.88% | Norm Diff (k=2): 1.5220
# Scouting Epoch 3/20 - Val NRMSE: 24.35% | Norm Diff (k=2): 0.4984
# Scouting Epoch 4/20 - Val NRMSE: 23.01% | Norm Diff (k=2): 0.2901
# Scouting Epoch 5/20 - Val NRMSE: 21.76% | Norm Diff (k=2): 0.2319
# Scouting Epoch 6/20 - Val NRMSE: 21.08% | Norm Diff (k=2): 0.1944
# Scouting Epoch 7/20 - Val NRMSE: 20.38% | Norm Diff (k=2): 0.1553
# Scouting Epoch 8/20 - Val NRMSE: 19.98% | Norm Diff (k=2): 0.1364
# Scouting Epoch 9/20 - Val NRMSE: 19.42% | Norm Diff (k=2): 0.1243
# Scouting Epoch 10/20 - Val NRMSE: 19.02% | Norm Diff (k=2): 0.1178
# Scouting Epoch 11/20 - Val NRMSE: 18.72% | Norm Diff (k=2): 0.1125
# Scouting Epoch 12/20 - Val NRMSE: 18.34% | Norm Diff (k=2): 0.0997
# Scouting Epoch 13/20 - Val NRMSE: 18.04% | Norm Diff (k=2): 0.0942
# Scouting Epoch 14/20 - Val NRMSE: 17.76% | Norm Diff (k=2): 0.0885
# Scouting Epoch 15/20 - Val NRMSE: 17.48% | Norm Diff (k=2): 0.0856
# Scouting Epoch 16/20 - Val NRMSE: 17.27% | Norm Diff (k=2): 0.0816
# Scouting Epoch 17/20 - Val NRMSE: 17.09% | Norm Diff (k=2): 0.0781
# Scouting Epoch 18/20 - Val NRMSE: 16.81% | Norm Diff (k=2): 0.0743
# Scouting Epoch 19/20 - Val NRMSE: 16.63% | Norm Diff (k=2): 0.0708
# Scouting Epoch 20/20 - Val NRMSE: 16.65% | Norm Diff (k=2): 0.0698
# Scouting run took 0.36 seconds.
#   Scouting Run 5/10...
#
# --- Starting SGD Scouting Run for 20 Epochs (Method: param_norm) ---
# Scouting Epoch 1/20 - Val NRMSE: 42.36% | Norm Diff (k=2): nan
# Scouting Epoch 2/20 - Val NRMSE: 29.45% | Norm Diff (k=2): 1.4268
# Scouting Epoch 3/20 - Val NRMSE: 25.33% | Norm Diff (k=2): 0.5589
# Scouting Epoch 4/20 - Val NRMSE: 23.19% | Norm Diff (k=2): 0.3599
# Scouting Epoch 5/20 - Val NRMSE: 21.83% | Norm Diff (k=2): 0.2600
# Scouting Epoch 6/20 - Val NRMSE: 20.81% | Norm Diff (k=2): 0.2065
# Scouting Epoch 7/20 - Val NRMSE: 20.10% | Norm Diff (k=2): 0.1715
# Scouting Epoch 8/20 - Val NRMSE: 19.71% | Norm Diff (k=2): 0.1500
# Scouting Epoch 9/20 - Val NRMSE: 19.03% | Norm Diff (k=2): 0.1293
# Scouting Epoch 10/20 - Val NRMSE: 18.62% | Norm Diff (k=2): 0.1186
# Scouting Epoch 11/20 - Val NRMSE: 18.32% | Norm Diff (k=2): 0.1085
# Scouting Epoch 12/20 - Val NRMSE: 17.95% | Norm Diff (k=2): 0.0962
# Scouting Epoch 13/20 - Val NRMSE: 17.77% | Norm Diff (k=2): 0.0904
# Scouting Epoch 14/20 - Val NRMSE: 17.41% | Norm Diff (k=2): 0.0840
# Scouting Epoch 15/20 - Val NRMSE: 17.15% | Norm Diff (k=2): 0.0835
# Scouting Epoch 16/20 - Val NRMSE: 16.94% | Norm Diff (k=2): 0.0770
# Scouting Epoch 17/20 - Val NRMSE: 16.74% | Norm Diff (k=2): 0.0742
# Scouting Epoch 18/20 - Val NRMSE: 16.51% | Norm Diff (k=2): 0.0685
# Scouting Epoch 19/20 - Val NRMSE: 16.33% | Norm Diff (k=2): 0.0676
# Scouting Epoch 20/20 - Val NRMSE: 16.14% | Norm Diff (k=2): 0.0645
# Scouting run took 0.37 seconds.
#   Scouting Run 6/10...
#
# --- Starting SGD Scouting Run for 20 Epochs (Method: param_norm) ---
# Scouting Epoch 1/20 - Val NRMSE: 39.08% | Norm Diff (k=2): nan
# Scouting Epoch 2/20 - Val NRMSE: 26.80% | Norm Diff (k=2): 1.4939
# Scouting Epoch 3/20 - Val NRMSE: 23.98% | Norm Diff (k=2): 0.4877
# Scouting Epoch 4/20 - Val NRMSE: 22.62% | Norm Diff (k=2): 0.2638
# Scouting Epoch 5/20 - Val NRMSE: 21.50% | Norm Diff (k=2): 0.2025
# Scouting Epoch 6/20 - Val NRMSE: 20.69% | Norm Diff (k=2): 0.1756
# Scouting Epoch 7/20 - Val NRMSE: 20.00% | Norm Diff (k=2): 0.1548
# Scouting Epoch 8/20 - Val NRMSE: 19.41% | Norm Diff (k=2): 0.1407
# Scouting Epoch 9/20 - Val NRMSE: 18.89% | Norm Diff (k=2): 0.1331
# Scouting Epoch 10/20 - Val NRMSE: 18.34% | Norm Diff (k=2): 0.1195
# Scouting Epoch 11/20 - Val NRMSE: 17.93% | Norm Diff (k=2): 0.1089
# Scouting Epoch 12/20 - Val NRMSE: 17.50% | Norm Diff (k=2): 0.1023
# Scouting Epoch 13/20 - Val NRMSE: 17.13% | Norm Diff (k=2): 0.0990
# Scouting Epoch 14/20 - Val NRMSE: 16.79% | Norm Diff (k=2): 0.0914
# Scouting Epoch 15/20 - Val NRMSE: 16.55% | Norm Diff (k=2): 0.0863
# Scouting Epoch 16/20 - Val NRMSE: 16.28% | Norm Diff (k=2): 0.0805
# Scouting Epoch 17/20 - Val NRMSE: 16.13% | Norm Diff (k=2): 0.0764
# Scouting Epoch 18/20 - Val NRMSE: 15.99% | Norm Diff (k=2): 0.0765
# Scouting Epoch 19/20 - Val NRMSE: 15.70% | Norm Diff (k=2): 0.0676
# Scouting Epoch 20/20 - Val NRMSE: 15.45% | Norm Diff (k=2): 0.0667
# Scouting run took 0.41 seconds.
#   Scouting Run 7/10...
#
# --- Starting SGD Scouting Run for 20 Epochs (Method: param_norm) ---
# Scouting Epoch 1/20 - Val NRMSE: 42.15% | Norm Diff (k=2): nan
# Scouting Epoch 2/20 - Val NRMSE: 27.97% | Norm Diff (k=2): 1.5595
# Scouting Epoch 3/20 - Val NRMSE: 25.38% | Norm Diff (k=2): 0.5175
# Scouting Epoch 4/20 - Val NRMSE: 23.84% | Norm Diff (k=2): 0.2952
# Scouting Epoch 5/20 - Val NRMSE: 22.74% | Norm Diff (k=2): 0.2249
# Scouting Epoch 6/20 - Val NRMSE: 21.94% | Norm Diff (k=2): 0.1811
# Scouting Epoch 7/20 - Val NRMSE: 21.18% | Norm Diff (k=2): 0.1554
# Scouting Epoch 8/20 - Val NRMSE: 20.55% | Norm Diff (k=2): 0.1424
# Scouting Epoch 9/20 - Val NRMSE: 20.05% | Norm Diff (k=2): 0.1315
# Scouting Epoch 10/20 - Val NRMSE: 19.46% | Norm Diff (k=2): 0.1235
# Scouting Epoch 11/20 - Val NRMSE: 19.15% | Norm Diff (k=2): 0.1131
# Scouting Epoch 12/20 - Val NRMSE: 18.62% | Norm Diff (k=2): 0.1053
# Scouting Epoch 13/20 - Val NRMSE: 18.40% | Norm Diff (k=2): 0.0994
# Scouting Epoch 14/20 - Val NRMSE: 17.88% | Norm Diff (k=2): 0.0936
# Scouting Epoch 15/20 - Val NRMSE: 17.53% | Norm Diff (k=2): 0.0952
# Scouting Epoch 16/20 - Val NRMSE: 17.31% | Norm Diff (k=2): 0.0826
# Scouting Epoch 17/20 - Val NRMSE: 17.11% | Norm Diff (k=2): 0.0865
# Scouting Epoch 18/20 - Val NRMSE: 16.73% | Norm Diff (k=2): 0.0769
# Scouting Epoch 19/20 - Val NRMSE: 16.48% | Norm Diff (k=2): 0.0753
# Scouting Epoch 20/20 - Val NRMSE: 16.23% | Norm Diff (k=2): 0.0714
# Scouting run took 0.36 seconds.
#   Scouting Run 8/10...
#
# --- Starting SGD Scouting Run for 20 Epochs (Method: param_norm) ---
# Scouting Epoch 1/20 - Val NRMSE: 44.54% | Norm Diff (k=2): nan
# Scouting Epoch 2/20 - Val NRMSE: 27.54% | Norm Diff (k=2): 1.6180
# Scouting Epoch 3/20 - Val NRMSE: 23.55% | Norm Diff (k=2): 0.5782
# Scouting Epoch 4/20 - Val NRMSE: 21.35% | Norm Diff (k=2): 0.3297
# Scouting Epoch 5/20 - Val NRMSE: 20.14% | Norm Diff (k=2): 0.2402
# Scouting Epoch 6/20 - Val NRMSE: 19.38% | Norm Diff (k=2): 0.1844
# Scouting Epoch 7/20 - Val NRMSE: 18.87% | Norm Diff (k=2): 0.1523
# Scouting Epoch 8/20 - Val NRMSE: 18.47% | Norm Diff (k=2): 0.1273
# Scouting Epoch 9/20 - Val NRMSE: 18.08% | Norm Diff (k=2): 0.1110
# Scouting Epoch 10/20 - Val NRMSE: 17.77% | Norm Diff (k=2): 0.1028
# Scouting Epoch 11/20 - Val NRMSE: 17.45% | Norm Diff (k=2): 0.0974
# Scouting Epoch 12/20 - Val NRMSE: 17.20% | Norm Diff (k=2): 0.0925
# Scouting Epoch 13/20 - Val NRMSE: 17.00% | Norm Diff (k=2): 0.0890
# Scouting Epoch 14/20 - Val NRMSE: 16.77% | Norm Diff (k=2): 0.0820
# Scouting Epoch 15/20 - Val NRMSE: 16.49% | Norm Diff (k=2): 0.0819
# Scouting Epoch 16/20 - Val NRMSE: 16.34% | Norm Diff (k=2): 0.0762
# Scouting Epoch 17/20 - Val NRMSE: 16.12% | Norm Diff (k=2): 0.0726
# Scouting Epoch 18/20 - Val NRMSE: 15.97% | Norm Diff (k=2): 0.0699
# Scouting Epoch 19/20 - Val NRMSE: 15.76% | Norm Diff (k=2): 0.0693
# Scouting Epoch 20/20 - Val NRMSE: 15.73% | Norm Diff (k=2): 0.0656
# Scouting run took 0.36 seconds.
#   Scouting Run 9/10...
#
# --- Starting SGD Scouting Run for 20 Epochs (Method: param_norm) ---
# Scouting Epoch 1/20 - Val NRMSE: 43.82% | Norm Diff (k=2): nan
# Scouting Epoch 2/20 - Val NRMSE: 28.23% | Norm Diff (k=2): 1.6395
# Scouting Epoch 3/20 - Val NRMSE: 24.82% | Norm Diff (k=2): 0.5208
# Scouting Epoch 4/20 - Val NRMSE: 23.03% | Norm Diff (k=2): 0.2910
# Scouting Epoch 5/20 - Val NRMSE: 21.69% | Norm Diff (k=2): 0.2221
# Scouting Epoch 6/20 - Val NRMSE: 20.77% | Norm Diff (k=2): 0.1846
# Scouting Epoch 7/20 - Val NRMSE: 20.08% | Norm Diff (k=2): 0.1544
# Scouting Epoch 8/20 - Val NRMSE: 19.47% | Norm Diff (k=2): 0.1355
# Scouting Epoch 9/20 - Val NRMSE: 18.96% | Norm Diff (k=2): 0.1254
# Scouting Epoch 10/20 - Val NRMSE: 18.52% | Norm Diff (k=2): 0.1170
# Scouting Epoch 11/20 - Val NRMSE: 18.17% | Norm Diff (k=2): 0.1083
# Scouting Epoch 12/20 - Val NRMSE: 17.75% | Norm Diff (k=2): 0.1026
# Scouting Epoch 13/20 - Val NRMSE: 17.43% | Norm Diff (k=2): 0.0967
# Scouting Epoch 14/20 - Val NRMSE: 17.09% | Norm Diff (k=2): 0.0905
# Scouting Epoch 15/20 - Val NRMSE: 16.80% | Norm Diff (k=2): 0.0851
# Scouting Epoch 16/20 - Val NRMSE: 16.57% | Norm Diff (k=2): 0.0830
# Scouting Epoch 17/20 - Val NRMSE: 16.40% | Norm Diff (k=2): 0.0794
# Scouting Epoch 18/20 - Val NRMSE: 16.12% | Norm Diff (k=2): 0.0751
# Scouting Epoch 19/20 - Val NRMSE: 15.87% | Norm Diff (k=2): 0.0765
# Scouting Epoch 20/20 - Val NRMSE: 15.71% | Norm Diff (k=2): 0.0680
# Scouting run took 0.36 seconds.
#   Scouting Run 10/10...
#
# --- Starting SGD Scouting Run for 20 Epochs (Method: param_norm) ---
# Scouting Epoch 1/20 - Val NRMSE: 39.63% | Norm Diff (k=2): nan
# Scouting Epoch 2/20 - Val NRMSE: 25.90% | Norm Diff (k=2): 1.5039
# Scouting Epoch 3/20 - Val NRMSE: 23.88% | Norm Diff (k=2): 0.4476
# Scouting Epoch 4/20 - Val NRMSE: 22.82% | Norm Diff (k=2): 0.2290
# Scouting Epoch 5/20 - Val NRMSE: 21.97% | Norm Diff (k=2): 0.1899
# Scouting Epoch 6/20 - Val NRMSE: 21.25% | Norm Diff (k=2): 0.1679
# Scouting Epoch 7/20 - Val NRMSE: 20.61% | Norm Diff (k=2): 0.1484
# Scouting Epoch 8/20 - Val NRMSE: 20.10% | Norm Diff (k=2): 0.1395
# Scouting Epoch 9/20 - Val NRMSE: 19.62% | Norm Diff (k=2): 0.1265
# Scouting Epoch 10/20 - Val NRMSE: 19.16% | Norm Diff (k=2): 0.1218
# Scouting Epoch 11/20 - Val NRMSE: 18.72% | Norm Diff (k=2): 0.1151
# Scouting Epoch 12/20 - Val NRMSE: 18.46% | Norm Diff (k=2): 0.1067
# Scouting Epoch 13/20 - Val NRMSE: 17.96% | Norm Diff (k=2): 0.1022
# Scouting Epoch 14/20 - Val NRMSE: 17.70% | Norm Diff (k=2): 0.0992
# Scouting Epoch 15/20 - Val NRMSE: 17.39% | Norm Diff (k=2): 0.0934
# Scouting Epoch 16/20 - Val NRMSE: 17.11% | Norm Diff (k=2): 0.0886
# Scouting Epoch 17/20 - Val NRMSE: 16.82% | Norm Diff (k=2): 0.0846
# Scouting Epoch 18/20 - Val NRMSE: 16.57% | Norm Diff (k=2): 0.0807
# Scouting Epoch 19/20 - Val NRMSE: 16.33% | Norm Diff (k=2): 0.0783
# Scouting Epoch 20/20 - Val NRMSE: 16.15% | Norm Diff (k=2): 0.0759
# Scouting run took 0.36 seconds.
#
# Aggregating scouting results...
#
# --- Suggested Thresholds Based on Averaged Scouting Run ---
# Average validation loss stabilized around epoch 11.
#
# Using 'Early Switch' (75th percentile) heuristic for 'param_norm'.
#
# Recommended Threshold for 'param_norm': 0.0945
# This threshold suggests a switch at Epoch: 14
#
# Plot saved as wine_sc_avg_val_p_100_0.007_0.0945.png
# Plot saved as wine_sc_avg_nrmse_p_100_0.007_0.0945.png

# %% [markdown]
# Run Main Experiment Loop:

# %%
all_runs_histories = {'SGD_Part1': [], 'SGD_Part2': [], 'NTK1_from_Switch': [], 'NTK2_from_Switch': [], 'NTK3_from_Switch': []}
all_runs_times = {'SGD (Part 1)': [], 'SGD (Part 2)': [], 'NTK1': [], 'NTK2': [], 'NTK3': []}
all_runs_test_metrics = {'Params_At_Switch': [], 'SGD_Full_Run': [], 'NTK1_from_Switch': [], 'NTK2_from_Switch': [], 'NTK3_from_Switch': []}
all_runs_switch_epochs = []

for seed in range(num_seeds):
    print(f"\n\n===== RUNNING EXPERIMENT FOR SEED {seed + 1}/{num_seeds} =====")
    key_init_params, key_sgd_part1, key_sgd_part2, key_ntk_subset_shuffle, key_ntk1, key_ntk2, key_ntk3 = run_keys[seed]
    initial_model_params = init_network_params(layer_dims, key_init_params)
    
    # For wine dataset, NTK subset is the full training set
    X_train_ntk_subset = X_train_full
    Y_train_reg_ntk_subset = Y_train_reg_full
    
    # --- Initial SGD Phase (up to switch point) ---
    params_at_switch, history_sgd_part1, time_sgd_part1, epoch_at_switch = run_sgd_monitoring_switch(
        initial_model_params, X_train_full, Y_train_reg_full, X_val_full, Y_val_reg_full,
        max_sgd_epochs=epochs_sgd_total_config, 
        batch_size=min(batch_size_config, X_train_full.shape[0]),
        lr_sgd=lr_sgd_config, key_sgd_loop=key_sgd_part1,
        switch_config=switch_config,
        X_ntk_monitor_subset=X_train_ntk_subset, num_classes=num_classes
    )
    all_runs_switch_epochs.append(epoch_at_switch)
    all_runs_histories['SGD_Part1'].append(history_sgd_part1)
    all_runs_times['SGD (Part 1)'].append(time_sgd_part1)
    test_l_s, test_nrmse_s = evaluate_on_test_jax(params_at_switch, X_test_full, Y_test_reg_full)
    all_runs_test_metrics['Params_At_Switch'].append({'loss': test_l_s, 'nrmse': test_nrmse_s})

    if epoch_at_switch >= epochs_sgd_total_config:
        print(f"WARNING: Switch condition not met for seed {seed+1}. Adjust thresholds or total epochs.")
        # Handle the case where the switch never happens
        # For this experiment, we'll record the full SGD run and skip NTK phases
        all_runs_histories['SGD_Part2'].append({'train_loss': [], 'train_nrmse': [], 'val_loss': [], 'val_nrmse': []}) # Empty history for part 2
        all_runs_times['SGD (Part 2)'].append(0.0)
        all_runs_test_metrics['SGD_Full_Run'].append({'loss': test_l_s, 'nrmse': test_nrmse_s})
        all_runs_test_metrics['NTK1_from_Switch'].append({'loss': np.nan, 'nrmse': np.nan})
        all_runs_test_metrics['NTK2_from_Switch'].append({'loss': np.nan, 'nrmse': np.nan})
        all_runs_test_metrics['NTK3_from_Switch'].append({'loss': np.nan, 'nrmse': np.nan})
        continue # Skip to the next seed

    full_sgd_epochs = epochs_sgd_total_config - epoch_at_switch
    num_ntk_iterations_to_run = epochs_sgd_total_config - epoch_at_switch - 3
    
    # --- Continued SGD Phase ---
    params_after_full_sgd, history_sgd_part2, time_sgd_part2 = run_sgd_epochs(
        copy.deepcopy(params_at_switch), X_train_full, Y_train_reg_full, X_val_full, Y_val_reg_full,
        start_epoch_idx=epoch_at_switch, num_epochs_to_run=full_sgd_epochs,
        batch_size=min(batch_size_config, X_train_full.shape[0]),
        lr_sgd=lr_sgd_config, key_sgd_loop=key_sgd_part2, phase_label="SGD (Part 2)"
    )
    all_runs_histories['SGD_Part2'].append(history_sgd_part2)
    all_runs_times['SGD (Part 2)'].append(time_sgd_part2)
    test_l_full, test_nrmse_full = evaluate_on_test_jax(params_after_full_sgd, X_test_full, Y_test_reg_full)
    all_runs_test_metrics['SGD_Full_Run'].append({'loss': test_l_full, 'nrmse': test_nrmse_full})
    
    # --- NTK Phases ---
    current_ntk_batch_size = min(batch_size_config, X_train_ntk_subset.shape[0])
    if num_ntk_iterations_to_run > 0:
        params_after_ntk1, history_ntk1, time_ntk1 = run_ntk1_phase(
            copy.deepcopy(params_at_switch), X_train_ntk_subset, Y_train_reg_ntk_subset,
            X_val_full, Y_val_reg_full, num_ntk_iterations_to_run, 
            current_ntk_batch_size, lr_ntk_iterative_config, key_ntk1)
        all_runs_histories['NTK1_from_Switch'].append(history_ntk1)
        all_runs_times['NTK1'].append(time_ntk1)
        test_l_ntk1, test_nrmse_ntk1 = evaluate_on_test_jax(params_after_ntk1, X_test_full, Y_test_reg_full)
        all_runs_test_metrics['NTK1_from_Switch'].append({'loss': test_l_ntk1, 'nrmse': test_nrmse_ntk1})

        params_after_ntk2, history_ntk2, time_ntk2 = run_ntk2_phase(
            copy.deepcopy(params_at_switch), X_train_ntk_subset, Y_train_reg_ntk_subset,
            X_val_full, Y_val_reg_full, epoch_at_switch, num_ntk_iterations_to_run,
            lr_ntk_iterative_config, taylor_order_ntk2=taylor_order_config)
        all_runs_histories['NTK2_from_Switch'].append(history_ntk2)
        all_runs_times['NTK2'].append(time_ntk2)
        test_l_ntk2, test_nrmse_ntk2 = evaluate_on_test_jax(params_after_ntk2, X_test_full, Y_test_reg_full)
        all_runs_test_metrics['NTK2_from_Switch'].append({'loss': test_l_ntk2, 'nrmse': test_nrmse_ntk2})

    params_after_ntk3, history_ntk3, time_ntk3 = run_ntk3_phase(
        copy.deepcopy(params_at_switch), X_train_ntk_subset, Y_train_reg_ntk_subset,
        X_val_full, Y_val_reg_full,
        lr_ntk=lr_ntk_iterative_config, # Pass the learning rate
        lambda_ntk3_reg=lambda_ntk3_config, 
        T_factor_ntk3=epochs_sgd_total_config,
        taylor_order_ntk3=taylor_order_config)
    all_runs_histories['NTK3_from_Switch'].append(history_ntk3)
    all_runs_times['NTK3'].append(time_ntk3)
    test_l_ntk3, test_nrmse_ntk3 = evaluate_on_test_jax(params_after_ntk3, X_test_full, Y_test_reg_full)
    all_runs_test_metrics['NTK3_from_Switch'].append({'loss': test_l_ntk3, 'nrmse': test_nrmse_ntk3})
# Out:
# ===== RUNNING EXPERIMENT FOR SEED 1/10 =====
#
# --- Starting SGD Phase (Monitoring for Switch using 'param_norm') ---
# SGD (Monitoring) Epoch 1 - Train L: 4.0886, NRMSE: 35.80% | Val L: 4.2073, NRMSE: 36.94% (took 0.09s)
# SGD (Monitoring) Epoch 2 - Train L: 2.0209, NRMSE: 25.17% | Val L: 2.2457, NRMSE: 26.99% | Param diff norm (k=2) = 1.412041 (took 0.02s)
# SGD (Monitoring) Epoch 3 - Train L: 1.6418, NRMSE: 22.69% | Val L: 1.8727, NRMSE: 24.64% | Param diff norm (k=2) = 0.441348 (took 0.02s)
# SGD (Monitoring) Epoch 4 - Train L: 1.4474, NRMSE: 21.30% | Val L: 1.6654, NRMSE: 23.24% | Param diff norm (k=2) = 0.245182 (took 0.02s)
# SGD (Monitoring) Epoch 5 - Train L: 1.3167, NRMSE: 20.32% | Val L: 1.5294, NRMSE: 22.27% | Param diff norm (k=2) = 0.192365 (took 0.02s)
# SGD (Monitoring) Epoch 6 - Train L: 1.2200, NRMSE: 19.56% | Val L: 1.4318, NRMSE: 21.55% | Param diff norm (k=2) = 0.163357 (took 0.02s)
# SGD (Monitoring) Epoch 7 - Train L: 1.1370, NRMSE: 18.88% | Val L: 1.3370, NRMSE: 20.82% | Param diff norm (k=2) = 0.144305 (took 0.02s)
# SGD (Monitoring) Epoch 8 - Train L: 1.0722, NRMSE: 18.33% | Val L: 1.2664, NRMSE: 20.27% | Param diff norm (k=2) = 0.128102 (took 0.02s)
# SGD (Monitoring) Epoch 9 - Train L: 1.0155, NRMSE: 17.84% | Val L: 1.2047, NRMSE: 19.76% | Param diff norm (k=2) = 0.119760 (took 0.02s)
# SGD (Monitoring) Epoch 10 - Train L: 0.9639, NRMSE: 17.38% | Val L: 1.1531, NRMSE: 19.34% | Param diff norm (k=2) = 0.113810 (took 0.02s)
# SGD (Monitoring) Epoch 11 - Train L: 0.9174, NRMSE: 16.96% | Val L: 1.0980, NRMSE: 18.87% | Param diff norm (k=2) = 0.108310 (took 0.02s)
# SGD (Monitoring) Epoch 12 - Train L: 0.8739, NRMSE: 16.55% | Val L: 1.0497, NRMSE: 18.45% | Param diff norm (k=2) = 0.101597 (took 0.02s)
# SGD (Monitoring) Epoch 13 - Train L: 0.8399, NRMSE: 16.23% | Val L: 1.0205, NRMSE: 18.19% | Param diff norm (k=2) = 0.096285 (took 0.02s)
# SGD (Monitoring) Epoch 14 - Train L: 0.8071, NRMSE: 15.91% | Val L: 0.9836, NRMSE: 17.86% | Param diff norm (k=2) = 0.091270 (took 0.02s)
# >>> Switching condition 'param_norm' met at epoch 14 over a 2-epoch window. <<<
# SGD monitoring phase (14 epochs) took 0.35 seconds.
#
# Test Set Evaluation - Loss: 0.8507, NRMSE: 16.23%
#
# --- Starting SGD (Part 2) Training Phase (Epochs 15 to 20) ---
# SGD (Part 2) Epoch 15 - Train L: 0.7742, NRMSE: 15.58% | Val L: 0.9409, NRMSE: 17.47%
# SGD (Part 2) Epoch 16 - Train L: 0.7442, NRMSE: 15.28% | Val L: 0.9036, NRMSE: 17.12%
# SGD (Part 2) Epoch 17 - Train L: 0.7181, NRMSE: 15.01% | Val L: 0.8735, NRMSE: 16.83%
# SGD (Part 2) Epoch 18 - Train L: 0.6955, NRMSE: 14.77% | Val L: 0.8528, NRMSE: 16.63%
# SGD (Part 2) Epoch 19 - Train L: 0.6726, NRMSE: 14.52% | Val L: 0.8272, NRMSE: 16.38%
# SGD (Part 2) Epoch 20 - Train L: 0.6512, NRMSE: 14.29% | Val L: 0.7985, NRMSE: 16.09%
# SGD (Part 2) phase (6 epochs) took 0.11 seconds.
#
# Test Set Evaluation - Loss: 0.6818, NRMSE: 14.53%
#
# --- Starting NTK 1 Phase ---
# NTK 1 Iter 1/3 - Train (full) L: 0.8005, NRMSE: 15.84% | Val (full) L: 0.9738, NRMSE: 17.77%
# NTK 1 Iter 2/3 - Train (full) L: 0.7955, NRMSE: 15.79% | Val (full) L: 0.9666, NRMSE: 17.70%
# NTK 1 Iter 3/3 - Train (full) L: 0.7912, NRMSE: 15.75% | Val (full) L: 0.9607, NRMSE: 17.65%
# NTK 1 phase (3 iterations) took 0.85 seconds.
#
# Test Set Evaluation - Loss: 0.8300, NRMSE: 16.03%
#
# --- Starting NTK 2 Phase ---
# NTK2: Computing J(X_train_ntk, Theta_0) and K_0...
# NTK2: J(X_train_ntk, Theta_0), K_0, and Error_0 computed.
# NTK 2 (Matrix Exp) Iter 15/17 - Train L: 0.7872, NRMSE: 15.71% | Val L: 0.9711, NRMSE: 17.75%
# NTK 2 (Matrix Exp) Iter 16/17 - Train L: 0.7798, NRMSE: 15.64% | Val L: 0.9661, NRMSE: 17.70%
# NTK 2 (Matrix Exp) Iter 17/17 - Train L: 0.7803, NRMSE: 15.64% | Val L: 0.9682, NRMSE: 17.72%
# NTK 2 phase (Matrix Exp, 3 iterations) took 0.45 seconds.
#
# Test Set Evaluation - Loss: 0.8575, NRMSE: 16.29%
#
# --- Starting NTK 3 Phase (Matrix Exp, T_factor=20) ---
# NTK3: Computing J(X_train_ntk, Theta_0), K_0, and Error_0...
# NTK3: J, K0, Error0 computed.
# NTK3: Solving for K0_dagger_times_Factor_times_Error (lambda_reg=0.01)...
# NTK3: Solved.
# NTK 3 (One-Shot) - Train (full) L: 0.4814, NRMSE: 12.29% | Val (full) L: 0.6248, NRMSE: 14.23%
# NTK 3 phase took 0.43 seconds.
#
# Test Set Evaluation - Loss: 0.5154, NRMSE: 12.63%
#
#
# ===== RUNNING EXPERIMENT FOR SEED 2/10 =====
#
# --- Starting SGD Phase (Monitoring for Switch using 'param_norm') ---
# SGD (Monitoring) Epoch 1 - Train L: 7.1167, NRMSE: 47.24% | Val L: 6.7537, NRMSE: 46.80% (took 0.02s)
# SGD (Monitoring) Epoch 2 - Train L: 2.2395, NRMSE: 26.50% | Val L: 2.1245, NRMSE: 26.25% | Param diff norm (k=2) = 1.627311 (took 0.02s)
# SGD (Monitoring) Epoch 3 - Train L: 1.7630, NRMSE: 23.51% | Val L: 1.7169, NRMSE: 23.60% | Param diff norm (k=2) = 0.578967 (took 0.02s)
# SGD (Monitoring) Epoch 4 - Train L: 1.5017, NRMSE: 21.70% | Val L: 1.5032, NRMSE: 22.08% | Param diff norm (k=2) = 0.288747 (took 0.02s)
# SGD (Monitoring) Epoch 5 - Train L: 1.3423, NRMSE: 20.51% | Val L: 1.3793, NRMSE: 21.15% | Param diff norm (k=2) = 0.217783 (took 0.02s)
# SGD (Monitoring) Epoch 6 - Train L: 1.2458, NRMSE: 19.76% | Val L: 1.3015, NRMSE: 20.54% | Param diff norm (k=2) = 0.175889 (took 0.02s)
# SGD (Monitoring) Epoch 7 - Train L: 1.1428, NRMSE: 18.93% | Val L: 1.2093, NRMSE: 19.80% | Param diff norm (k=2) = 0.150438 (took 0.02s)
# SGD (Monitoring) Epoch 8 - Train L: 1.0709, NRMSE: 18.32% | Val L: 1.1483, NRMSE: 19.30% | Param diff norm (k=2) = 0.137515 (took 0.02s)
# SGD (Monitoring) Epoch 9 - Train L: 1.0100, NRMSE: 17.80% | Val L: 1.0963, NRMSE: 18.86% | Param diff norm (k=2) = 0.121566 (took 0.02s)
# SGD (Monitoring) Epoch 10 - Train L: 0.9579, NRMSE: 17.33% | Val L: 1.0506, NRMSE: 18.46% | Param diff norm (k=2) = 0.113262 (took 0.02s)
# SGD (Monitoring) Epoch 11 - Train L: 0.9125, NRMSE: 16.91% | Val L: 1.0112, NRMSE: 18.11% | Param diff norm (k=2) = 0.105807 (took 0.02s)
# SGD (Monitoring) Epoch 12 - Train L: 0.8723, NRMSE: 16.54% | Val L: 0.9766, NRMSE: 17.80% | Param diff norm (k=2) = 0.100651 (took 0.02s)
# SGD (Monitoring) Epoch 13 - Train L: 0.8350, NRMSE: 16.18% | Val L: 0.9384, NRMSE: 17.44% | Param diff norm (k=2) = 0.094421 (took 0.02s)
# >>> Switching condition 'param_norm' met at epoch 13 over a 2-epoch window. <<<
# SGD monitoring phase (13 epochs) took 0.25 seconds.
#
# Test Set Evaluation - Loss: 0.8032, NRMSE: 15.77%
#
# --- Starting SGD (Part 2) Training Phase (Epochs 14 to 20) ---
# SGD (Part 2) Epoch 14 - Train L: 0.8055, NRMSE: 15.89% | Val L: 0.9049, NRMSE: 17.13%
# SGD (Part 2) Epoch 15 - Train L: 0.7753, NRMSE: 15.59% | Val L: 0.8828, NRMSE: 16.92%
# SGD (Part 2) Epoch 16 - Train L: 0.7557, NRMSE: 15.39% | Val L: 0.8493, NRMSE: 16.60%
# SGD (Part 2) Epoch 17 - Train L: 0.7228, NRMSE: 15.05% | Val L: 0.8282, NRMSE: 16.39%
# SGD (Part 2) Epoch 18 - Train L: 0.7086, NRMSE: 14.91% | Val L: 0.8173, NRMSE: 16.28%
# SGD (Part 2) Epoch 19 - Train L: 0.6792, NRMSE: 14.59% | Val L: 0.7825, NRMSE: 15.93%
# SGD (Part 2) Epoch 20 - Train L: 0.6607, NRMSE: 14.39% | Val L: 0.7605, NRMSE: 15.70%
# SGD (Part 2) phase (7 epochs) took 0.12 seconds.
#
# Test Set Evaluation - Loss: 0.6412, NRMSE: 14.09%
#
# --- Starting NTK 1 Phase ---
# NTK 1 Iter 1/4 - Train (full) L: 0.8305, NRMSE: 16.14% | Val (full) L: 0.9332, NRMSE: 17.40%
# NTK 1 Iter 2/4 - Train (full) L: 0.8261, NRMSE: 16.09% | Val (full) L: 0.9285, NRMSE: 17.35%
# NTK 1 Iter 3/4 - Train (full) L: 0.8220, NRMSE: 16.05% | Val (full) L: 0.9240, NRMSE: 17.31%
# NTK 1 Iter 4/4 - Train (full) L: 0.8179, NRMSE: 16.01% | Val (full) L: 0.9198, NRMSE: 17.27%
# NTK 1 phase (4 iterations) took 0.51 seconds.
#
# Test Set Evaluation - Loss: 0.7876, NRMSE: 15.61%
#
# --- Starting NTK 2 Phase ---
# NTK2: Computing J(X_train_ntk, Theta_0) and K_0...
# NTK2: J(X_train_ntk, Theta_0), K_0, and Error_0 computed.
# NTK 2 (Matrix Exp) Iter 14/17 - Train L: 0.8093, NRMSE: 15.93% | Val L: 0.9222, NRMSE: 17.29%
# NTK 2 (Matrix Exp) Iter 15/17 - Train L: 0.7939, NRMSE: 15.78% | Val L: 0.9104, NRMSE: 17.18%
# NTK 2 (Matrix Exp) Iter 16/17 - Train L: 0.7853, NRMSE: 15.69% | Val L: 0.9036, NRMSE: 17.12%
# NTK 2 (Matrix Exp) Iter 17/17 - Train L: 0.7808, NRMSE: 15.65% | Val L: 0.8986, NRMSE: 17.07%
# NTK 2 phase (Matrix Exp, 4 iterations) took 0.51 seconds.
#
# Test Set Evaluation - Loss: 0.7857, NRMSE: 15.59%
#
# --- Starting NTK 3 Phase (Matrix Exp, T_factor=20) ---
# NTK3: Computing J(X_train_ntk, Theta_0), K_0, and Error_0...
# NTK3: J, K0, Error0 computed.
# NTK3: Solving for K0_dagger_times_Factor_times_Error (lambda_reg=0.01)...
# NTK3: Solved.
# NTK 3 (One-Shot) - Train (full) L: 0.4094, NRMSE: 11.33% | Val (full) L: 0.5216, NRMSE: 13.01%
# NTK 3 phase took 0.43 seconds.
#
# Test Set Evaluation - Loss: 0.4081, NRMSE: 11.24%
#
#
# ===== RUNNING EXPERIMENT FOR SEED 3/10 =====
#
# --- Starting SGD Phase (Monitoring for Switch using 'param_norm') ---
# SGD (Monitoring) Epoch 1 - Train L: 5.9874, NRMSE: 43.33% | Val L: 5.8948, NRMSE: 43.72% (took 0.02s)
# SGD (Monitoring) Epoch 2 - Train L: 2.1279, NRMSE: 25.83% | Val L: 2.0691, NRMSE: 25.90% | Param diff norm (k=2) = 1.590453 (took 0.02s)
# SGD (Monitoring) Epoch 3 - Train L: 1.6622, NRMSE: 22.83% | Val L: 1.6645, NRMSE: 23.23% | Param diff norm (k=2) = 0.529358 (took 0.02s)
# SGD (Monitoring) Epoch 4 - Train L: 1.4274, NRMSE: 21.15% | Val L: 1.4568, NRMSE: 21.74% | Param diff norm (k=2) = 0.286327 (took 0.02s)
# SGD (Monitoring) Epoch 5 - Train L: 1.2687, NRMSE: 19.94% | Val L: 1.3271, NRMSE: 20.75% | Param diff norm (k=2) = 0.208643 (took 0.02s)
# SGD (Monitoring) Epoch 6 - Train L: 1.1576, NRMSE: 19.05% | Val L: 1.2366, NRMSE: 20.03% | Param diff norm (k=2) = 0.175685 (took 0.02s)
# SGD (Monitoring) Epoch 7 - Train L: 1.0826, NRMSE: 18.42% | Val L: 1.1736, NRMSE: 19.51% | Param diff norm (k=2) = 0.146733 (took 0.02s)
# SGD (Monitoring) Epoch 8 - Train L: 1.0224, NRMSE: 17.90% | Val L: 1.1233, NRMSE: 19.09% | Param diff norm (k=2) = 0.122343 (took 0.02s)
# SGD (Monitoring) Epoch 9 - Train L: 0.9717, NRMSE: 17.45% | Val L: 1.0801, NRMSE: 18.72% | Param diff norm (k=2) = 0.114212 (took 0.02s)
# SGD (Monitoring) Epoch 10 - Train L: 0.9281, NRMSE: 17.06% | Val L: 1.0432, NRMSE: 18.39% | Param diff norm (k=2) = 0.105471 (took 0.02s)
# SGD (Monitoring) Epoch 11 - Train L: 0.8885, NRMSE: 16.69% | Val L: 1.0082, NRMSE: 18.08% | Param diff norm (k=2) = 0.096420 (took 0.02s)
# SGD (Monitoring) Epoch 12 - Train L: 0.8534, NRMSE: 16.36% | Val L: 0.9726, NRMSE: 17.76% | Param diff norm (k=2) = 0.093587 (took 0.02s)
# >>> Switching condition 'param_norm' met at epoch 12 over a 2-epoch window. <<<
# SGD monitoring phase (12 epochs) took 0.22 seconds.
#
# Test Set Evaluation - Loss: 0.8328, NRMSE: 16.05%
#
# --- Starting SGD (Part 2) Training Phase (Epochs 13 to 20) ---
# SGD (Part 2) Epoch 13 - Train L: 0.8217, NRMSE: 16.05% | Val L: 0.9490, NRMSE: 17.54%
# SGD (Part 2) Epoch 14 - Train L: 0.7911, NRMSE: 15.75% | Val L: 0.9178, NRMSE: 17.25%
# SGD (Part 2) Epoch 15 - Train L: 0.7648, NRMSE: 15.49% | Val L: 0.8900, NRMSE: 16.99%
# SGD (Part 2) Epoch 16 - Train L: 0.7416, NRMSE: 15.25% | Val L: 0.8752, NRMSE: 16.85%
# SGD (Part 2) Epoch 17 - Train L: 0.7157, NRMSE: 14.98% | Val L: 0.8432, NRMSE: 16.54%
# SGD (Part 2) Epoch 18 - Train L: 0.6983, NRMSE: 14.80% | Val L: 0.8347, NRMSE: 16.45%
# SGD (Part 2) Epoch 19 - Train L: 0.6745, NRMSE: 14.54% | Val L: 0.8092, NRMSE: 16.20%
# SGD (Part 2) Epoch 20 - Train L: 0.6607, NRMSE: 14.39% | Val L: 0.8019, NRMSE: 16.13%
# SGD (Part 2) phase (8 epochs) took 0.13 seconds.
#
# Test Set Evaluation - Loss: 0.6589, NRMSE: 14.28%
#
# --- Starting NTK 1 Phase ---
# NTK 1 Iter 1/5 - Train (full) L: 0.8488, NRMSE: 16.31% | Val (full) L: 0.9691, NRMSE: 17.73%
# NTK 1 Iter 2/5 - Train (full) L: 0.8445, NRMSE: 16.27% | Val (full) L: 0.9657, NRMSE: 17.70%
# NTK 1 Iter 3/5 - Train (full) L: 0.8404, NRMSE: 16.23% | Val (full) L: 0.9621, NRMSE: 17.66%
# NTK 1 Iter 4/5 - Train (full) L: 0.8363, NRMSE: 16.19% | Val (full) L: 0.9586, NRMSE: 17.63%
# NTK 1 Iter 5/5 - Train (full) L: 0.8323, NRMSE: 16.15% | Val (full) L: 0.9550, NRMSE: 17.60%
# NTK 1 phase (5 iterations) took 0.54 seconds.
#
# Test Set Evaluation - Loss: 0.8146, NRMSE: 15.88%
#
# --- Starting NTK 2 Phase ---
# NTK2: Computing J(X_train_ntk, Theta_0) and K_0...
# NTK2: J(X_train_ntk, Theta_0), K_0, and Error_0 computed.
# NTK 2 (Matrix Exp) Iter 13/17 - Train L: 0.8243, NRMSE: 16.08% | Val L: 0.9532, NRMSE: 17.58%
# NTK 2 (Matrix Exp) Iter 14/17 - Train L: 0.8067, NRMSE: 15.90% | Val L: 0.9386, NRMSE: 17.45%
# NTK 2 (Matrix Exp) Iter 15/17 - Train L: 0.7976, NRMSE: 15.81% | Val L: 0.9278, NRMSE: 17.35%
# NTK 2 (Matrix Exp) Iter 16/17 - Train L: 0.7957, NRMSE: 15.79% | Val L: 0.9210, NRMSE: 17.28%
# NTK 2 (Matrix Exp) Iter 17/17 - Train L: 0.8011, NRMSE: 15.85% | Val L: 0.9202, NRMSE: 17.27%
# NTK 2 phase (Matrix Exp, 5 iterations) took 0.62 seconds.
#
# Test Set Evaluation - Loss: 0.8104, NRMSE: 15.84%
#
# --- Starting NTK 3 Phase (Matrix Exp, T_factor=20) ---
# NTK3: Computing J(X_train_ntk, Theta_0), K_0, and Error_0...
# NTK3: J, K0, Error0 computed.
# NTK3: Solving for K0_dagger_times_Factor_times_Error (lambda_reg=0.01)...
# NTK3: Solved.
# NTK 3 (One-Shot) - Train (full) L: 0.4205, NRMSE: 11.48% | Val (full) L: 0.5255, NRMSE: 13.05%
# NTK 3 phase took 0.44 seconds.
#
# Test Set Evaluation - Loss: 0.4243, NRMSE: 11.46%
#
#
# ===== RUNNING EXPERIMENT FOR SEED 4/10 =====
#
# --- Starting SGD Phase (Monitoring for Switch using 'param_norm') ---
# SGD (Monitoring) Epoch 1 - Train L: 6.3690, NRMSE: 44.69% | Val L: 6.3407, NRMSE: 45.35% (took 0.02s)
# SGD (Monitoring) Epoch 2 - Train L: 2.2123, NRMSE: 26.34% | Val L: 2.2386, NRMSE: 26.94% | Param diff norm (k=2) = 1.636041 (took 0.02s)
# SGD (Monitoring) Epoch 3 - Train L: 1.7461, NRMSE: 23.40% | Val L: 1.7937, NRMSE: 24.12% | Param diff norm (k=2) = 0.536916 (took 0.02s)
# SGD (Monitoring) Epoch 4 - Train L: 1.4949, NRMSE: 21.65% | Val L: 1.5634, NRMSE: 22.52% | Param diff norm (k=2) = 0.278253 (took 0.02s)
# SGD (Monitoring) Epoch 5 - Train L: 1.3319, NRMSE: 20.43% | Val L: 1.4162, NRMSE: 21.43% | Param diff norm (k=2) = 0.214800 (took 0.02s)
# SGD (Monitoring) Epoch 6 - Train L: 1.2237, NRMSE: 19.59% | Val L: 1.3181, NRMSE: 20.67% | Param diff norm (k=2) = 0.176671 (took 0.02s)
# SGD (Monitoring) Epoch 7 - Train L: 1.1331, NRMSE: 18.85% | Val L: 1.2366, NRMSE: 20.03% | Param diff norm (k=2) = 0.150527 (took 0.02s)
# SGD (Monitoring) Epoch 8 - Train L: 1.0639, NRMSE: 18.26% | Val L: 1.1746, NRMSE: 19.52% | Param diff norm (k=2) = 0.133853 (took 0.02s)
# SGD (Monitoring) Epoch 9 - Train L: 1.0054, NRMSE: 17.75% | Val L: 1.1205, NRMSE: 19.06% | Param diff norm (k=2) = 0.121858 (took 0.02s)
# SGD (Monitoring) Epoch 10 - Train L: 0.9506, NRMSE: 17.26% | Val L: 1.0703, NRMSE: 18.63% | Param diff norm (k=2) = 0.114546 (took 0.02s)
# SGD (Monitoring) Epoch 11 - Train L: 0.9049, NRMSE: 16.84% | Val L: 1.0253, NRMSE: 18.23% | Param diff norm (k=2) = 0.108761 (took 0.02s)
# SGD (Monitoring) Epoch 12 - Train L: 0.8639, NRMSE: 16.46% | Val L: 0.9868, NRMSE: 17.89% | Param diff norm (k=2) = 0.100876 (took 0.02s)
# SGD (Monitoring) Epoch 13 - Train L: 0.8268, NRMSE: 16.10% | Val L: 0.9553, NRMSE: 17.60% | Param diff norm (k=2) = 0.093844 (took 0.02s)
# >>> Switching condition 'param_norm' met at epoch 13 over a 2-epoch window. <<<
# SGD monitoring phase (13 epochs) took 0.24 seconds.
#
# Test Set Evaluation - Loss: 0.8776, NRMSE: 16.48%
#
# --- Starting SGD (Part 2) Training Phase (Epochs 14 to 20) ---
# SGD (Part 2) Epoch 14 - Train L: 0.7928, NRMSE: 15.77% | Val L: 0.9265, NRMSE: 17.33%
# SGD (Part 2) Epoch 15 - Train L: 0.7661, NRMSE: 15.50% | Val L: 0.9077, NRMSE: 17.16%
# SGD (Part 2) Epoch 16 - Train L: 0.7418, NRMSE: 15.25% | Val L: 0.8727, NRMSE: 16.82%
# SGD (Part 2) Epoch 17 - Train L: 0.7129, NRMSE: 14.95% | Val L: 0.8461, NRMSE: 16.56%
# SGD (Part 2) Epoch 18 - Train L: 0.6850, NRMSE: 14.65% | Val L: 0.8250, NRMSE: 16.36%
# SGD (Part 2) Epoch 19 - Train L: 0.6631, NRMSE: 14.42% | Val L: 0.8071, NRMSE: 16.18%
# SGD (Part 2) Epoch 20 - Train L: 0.6432, NRMSE: 14.20% | Val L: 0.7893, NRMSE: 16.00%
# SGD (Part 2) phase (7 epochs) took 0.12 seconds.
#
# Test Set Evaluation - Loss: 0.6892, NRMSE: 14.60%
#
# --- Starting NTK 1 Phase ---
# NTK 1 Iter 1/4 - Train (full) L: 0.8222, NRMSE: 16.06% | Val (full) L: 0.9514, NRMSE: 17.57%
# NTK 1 Iter 2/4 - Train (full) L: 0.8178, NRMSE: 16.01% | Val (full) L: 0.9476, NRMSE: 17.53%
# NTK 1 Iter 3/4 - Train (full) L: 0.8135, NRMSE: 15.97% | Val (full) L: 0.9438, NRMSE: 17.49%
# NTK 1 Iter 4/4 - Train (full) L: 0.8092, NRMSE: 15.93% | Val (full) L: 0.9399, NRMSE: 17.46%
# NTK 1 phase (4 iterations) took 0.51 seconds.
#
# Test Set Evaluation - Loss: 0.8614, NRMSE: 16.33%
#
# --- Starting NTK 2 Phase ---
# NTK2: Computing J(X_train_ntk, Theta_0) and K_0...
# NTK2: J(X_train_ntk, Theta_0), K_0, and Error_0 computed.
# NTK 2 (Matrix Exp) Iter 14/17 - Train L: 0.8026, NRMSE: 15.86% | Val L: 0.9379, NRMSE: 17.44%
# NTK 2 (Matrix Exp) Iter 15/17 - Train L: 0.7906, NRMSE: 15.74% | Val L: 0.9279, NRMSE: 17.35%
# NTK 2 (Matrix Exp) Iter 16/17 - Train L: 0.7871, NRMSE: 15.71% | Val L: 0.9261, NRMSE: 17.33%
# NTK 2 (Matrix Exp) Iter 17/17 - Train L: 0.7901, NRMSE: 15.74% | Val L: 0.9297, NRMSE: 17.36%
# NTK 2 phase (Matrix Exp, 4 iterations) took 0.52 seconds.
#
# Test Set Evaluation - Loss: 0.8871, NRMSE: 16.57%
#
# --- Starting NTK 3 Phase (Matrix Exp, T_factor=20) ---
# NTK3: Computing J(X_train_ntk, Theta_0), K_0, and Error_0...
# NTK3: J, K0, Error0 computed.
# NTK3: Solving for K0_dagger_times_Factor_times_Error (lambda_reg=0.01)...
# NTK3: Solved.
# NTK 3 (One-Shot) - Train (full) L: 0.4127, NRMSE: 11.38% | Val (full) L: 0.5643, NRMSE: 13.53%
# NTK 3 phase took 0.43 seconds.
#
# Test Set Evaluation - Loss: 0.4770, NRMSE: 12.15%
#
#
# ===== RUNNING EXPERIMENT FOR SEED 5/10 =====
#
# --- Starting SGD Phase (Monitoring for Switch using 'param_norm') ---
# SGD (Monitoring) Epoch 1 - Train L: 3.4520, NRMSE: 32.90% | Val L: 3.6032, NRMSE: 34.18% (took 0.02s)
# SGD (Monitoring) Epoch 2 - Train L: 1.8364, NRMSE: 24.00% | Val L: 2.0049, NRMSE: 25.50% | Param diff norm (k=2) = 1.444577 (took 0.02s)
# SGD (Monitoring) Epoch 3 - Train L: 1.5270, NRMSE: 21.88% | Val L: 1.6976, NRMSE: 23.46% | Param diff norm (k=2) = 0.390649 (took 0.02s)
# SGD (Monitoring) Epoch 4 - Train L: 1.3658, NRMSE: 20.69% | Val L: 1.5422, NRMSE: 22.36% | Param diff norm (k=2) = 0.225057 (took 0.02s)
# SGD (Monitoring) Epoch 5 - Train L: 1.2609, NRMSE: 19.88% | Val L: 1.4385, NRMSE: 21.60% | Param diff norm (k=2) = 0.176063 (took 0.02s)
# SGD (Monitoring) Epoch 6 - Train L: 1.1724, NRMSE: 19.17% | Val L: 1.3510, NRMSE: 20.93% | Param diff norm (k=2) = 0.149248 (took 0.02s)
# SGD (Monitoring) Epoch 7 - Train L: 1.1036, NRMSE: 18.60% | Val L: 1.2826, NRMSE: 20.39% | Param diff norm (k=2) = 0.132821 (took 0.02s)
# SGD (Monitoring) Epoch 8 - Train L: 1.0450, NRMSE: 18.10% | Val L: 1.2201, NRMSE: 19.89% | Param diff norm (k=2) = 0.120608 (took 0.02s)
# SGD (Monitoring) Epoch 9 - Train L: 0.9926, NRMSE: 17.64% | Val L: 1.1661, NRMSE: 19.45% | Param diff norm (k=2) = 0.113056 (took 0.02s)
# SGD (Monitoring) Epoch 10 - Train L: 0.9467, NRMSE: 17.23% | Val L: 1.1168, NRMSE: 19.03% | Param diff norm (k=2) = 0.106354 (took 0.02s)
# SGD (Monitoring) Epoch 11 - Train L: 0.9068, NRMSE: 16.86% | Val L: 1.0723, NRMSE: 18.65% | Param diff norm (k=2) = 0.098485 (took 0.02s)
# SGD (Monitoring) Epoch 12 - Train L: 0.8721, NRMSE: 16.54% | Val L: 1.0340, NRMSE: 18.31% | Param diff norm (k=2) = 0.095420 (took 0.02s)
# SGD (Monitoring) Epoch 13 - Train L: 0.8378, NRMSE: 16.21% | Val L: 0.9913, NRMSE: 17.93% | Param diff norm (k=2) = 0.089686 (took 0.02s)
# >>> Switching condition 'param_norm' met at epoch 13 over a 2-epoch window. <<<
# SGD monitoring phase (13 epochs) took 0.24 seconds.
#
# Test Set Evaluation - Loss: 0.8674, NRMSE: 16.38%
#
# --- Starting SGD (Part 2) Training Phase (Epochs 14 to 20) ---
# SGD (Part 2) Epoch 14 - Train L: 0.8066, NRMSE: 15.90% | Val L: 0.9594, NRMSE: 17.64%
# SGD (Part 2) Epoch 15 - Train L: 0.7813, NRMSE: 15.65% | Val L: 0.9354, NRMSE: 17.42%
# SGD (Part 2) Epoch 16 - Train L: 0.7555, NRMSE: 15.39% | Val L: 0.9022, NRMSE: 17.10%
# SGD (Part 2) Epoch 17 - Train L: 0.7381, NRMSE: 15.21% | Val L: 0.8742, NRMSE: 16.84%
# SGD (Part 2) Epoch 18 - Train L: 0.7169, NRMSE: 14.99% | Val L: 0.8498, NRMSE: 16.60%
# SGD (Part 2) Epoch 19 - Train L: 0.6912, NRMSE: 14.72% | Val L: 0.8393, NRMSE: 16.50%
# SGD (Part 2) Epoch 20 - Train L: 0.6893, NRMSE: 14.70% | Val L: 0.8454, NRMSE: 16.56%
# SGD (Part 2) phase (7 epochs) took 0.12 seconds.
#
# Test Set Evaluation - Loss: 0.7302, NRMSE: 15.03%
#
# --- Starting NTK 1 Phase ---
# NTK 1 Iter 1/4 - Train (full) L: 0.8335, NRMSE: 16.17% | Val (full) L: 0.9877, NRMSE: 17.90%
# NTK 1 Iter 2/4 - Train (full) L: 0.8294, NRMSE: 16.13% | Val (full) L: 0.9840, NRMSE: 17.86%
# NTK 1 Iter 3/4 - Train (full) L: 0.8255, NRMSE: 16.09% | Val (full) L: 0.9802, NRMSE: 17.83%
# NTK 1 Iter 4/4 - Train (full) L: 0.8217, NRMSE: 16.05% | Val (full) L: 0.9763, NRMSE: 17.79%
# NTK 1 phase (4 iterations) took 0.51 seconds.
#
# Test Set Evaluation - Loss: 0.8522, NRMSE: 16.24%
#
# --- Starting NTK 2 Phase ---
# NTK2: Computing J(X_train_ntk, Theta_0) and K_0...
# NTK2: J(X_train_ntk, Theta_0), K_0, and Error_0 computed.
# NTK 2 (Matrix Exp) Iter 14/17 - Train L: 0.8086, NRMSE: 15.92% | Val L: 0.9693, NRMSE: 17.73%
# NTK 2 (Matrix Exp) Iter 15/17 - Train L: 0.7929, NRMSE: 15.77% | Val L: 0.9568, NRMSE: 17.61%
# NTK 2 (Matrix Exp) Iter 16/17 - Train L: 0.7862, NRMSE: 15.70% | Val L: 0.9518, NRMSE: 17.57%
# NTK 2 (Matrix Exp) Iter 17/17 - Train L: 0.7870, NRMSE: 15.71% | Val L: 0.9537, NRMSE: 17.59%
# NTK 2 phase (Matrix Exp, 4 iterations) took 0.48 seconds.
#
# Test Set Evaluation - Loss: 0.8560, NRMSE: 16.28%
#
# --- Starting NTK 3 Phase (Matrix Exp, T_factor=20) ---
# NTK3: Computing J(X_train_ntk, Theta_0), K_0, and Error_0...
# NTK3: J, K0, Error0 computed.
# NTK3: Solving for K0_dagger_times_Factor_times_Error (lambda_reg=0.01)...
# NTK3: Solved.
# NTK 3 (One-Shot) - Train (full) L: 0.3969, NRMSE: 11.16% | Val (full) L: 0.4928, NRMSE: 12.64%
# NTK 3 phase took 0.43 seconds.
#
# Test Set Evaluation - Loss: 0.4415, NRMSE: 11.69%
#
#
# ===== RUNNING EXPERIMENT FOR SEED 6/10 =====
#
# --- Starting SGD Phase (Monitoring for Switch using 'param_norm') ---
# SGD (Monitoring) Epoch 1 - Train L: 5.8038, NRMSE: 42.66% | Val L: 6.0175, NRMSE: 44.17% (took 0.02s)
# SGD (Monitoring) Epoch 2 - Train L: 2.7178, NRMSE: 29.19% | Val L: 2.9098, NRMSE: 30.72% | Param diff norm (k=2) = 1.486011 (took 0.02s)
# SGD (Monitoring) Epoch 3 - Train L: 2.0281, NRMSE: 25.22% | Val L: 2.1737, NRMSE: 26.55% | Param diff norm (k=2) = 0.549154 (took 0.02s)
# SGD (Monitoring) Epoch 4 - Train L: 1.6649, NRMSE: 22.85% | Val L: 1.7859, NRMSE: 24.07% | Param diff norm (k=2) = 0.335224 (took 0.02s)
# SGD (Monitoring) Epoch 5 - Train L: 1.4341, NRMSE: 21.20% | Val L: 1.5431, NRMSE: 22.37% | Param diff norm (k=2) = 0.258401 (took 0.02s)
# SGD (Monitoring) Epoch 6 - Train L: 1.2856, NRMSE: 20.08% | Val L: 1.3889, NRMSE: 21.22% | Param diff norm (k=2) = 0.207580 (took 0.02s)
# SGD (Monitoring) Epoch 7 - Train L: 1.1763, NRMSE: 19.20% | Val L: 1.2767, NRMSE: 20.35% | Param diff norm (k=2) = 0.170664 (took 0.02s)
# SGD (Monitoring) Epoch 8 - Train L: 1.0926, NRMSE: 18.51% | Val L: 1.1949, NRMSE: 19.69% | Param diff norm (k=2) = 0.145766 (took 0.02s)
# SGD (Monitoring) Epoch 9 - Train L: 1.0249, NRMSE: 17.93% | Val L: 1.1254, NRMSE: 19.10% | Param diff norm (k=2) = 0.132363 (took 0.02s)
# SGD (Monitoring) Epoch 10 - Train L: 0.9628, NRMSE: 17.37% | Val L: 1.0587, NRMSE: 18.53% | Param diff norm (k=2) = 0.123688 (took 0.02s)
# SGD (Monitoring) Epoch 11 - Train L: 0.9098, NRMSE: 16.89% | Val L: 1.0053, NRMSE: 18.06% | Param diff norm (k=2) = 0.114199 (took 0.02s)
# SGD (Monitoring) Epoch 12 - Train L: 0.8671, NRMSE: 16.49% | Val L: 0.9643, NRMSE: 17.68% | Param diff norm (k=2) = 0.103429 (took 0.02s)
# SGD (Monitoring) Epoch 13 - Train L: 0.8283, NRMSE: 16.12% | Val L: 0.9211, NRMSE: 17.28% | Param diff norm (k=2) = 0.095412 (took 0.02s)
# SGD (Monitoring) Epoch 14 - Train L: 0.7936, NRMSE: 15.77% | Val L: 0.8862, NRMSE: 16.95% | Param diff norm (k=2) = 0.093585 (took 0.02s)
# >>> Switching condition 'param_norm' met at epoch 14 over a 2-epoch window. <<<
# SGD monitoring phase (14 epochs) took 0.26 seconds.
#
# Test Set Evaluation - Loss: 0.8354, NRMSE: 16.08%
#
# --- Starting SGD (Part 2) Training Phase (Epochs 15 to 20) ---
# SGD (Part 2) Epoch 15 - Train L: 0.7622, NRMSE: 15.46% | Val L: 0.8643, NRMSE: 16.74%
# SGD (Part 2) Epoch 16 - Train L: 0.7328, NRMSE: 15.16% | Val L: 0.8316, NRMSE: 16.42%
# SGD (Part 2) Epoch 17 - Train L: 0.7089, NRMSE: 14.91% | Val L: 0.8080, NRMSE: 16.19%
# SGD (Part 2) Epoch 18 - Train L: 0.6827, NRMSE: 14.63% | Val L: 0.7734, NRMSE: 15.84%
# SGD (Part 2) Epoch 19 - Train L: 0.6624, NRMSE: 14.41% | Val L: 0.7586, NRMSE: 15.68%
# SGD (Part 2) Epoch 20 - Train L: 0.6411, NRMSE: 14.18% | Val L: 0.7357, NRMSE: 15.45%
# SGD (Part 2) phase (6 epochs) took 0.10 seconds.
#
# Test Set Evaluation - Loss: 0.6813, NRMSE: 14.52%
#
# --- Starting NTK 1 Phase ---
# NTK 1 Iter 1/3 - Train (full) L: 0.7882, NRMSE: 15.72% | Val (full) L: 0.8823, NRMSE: 16.92%
# NTK 1 Iter 2/3 - Train (full) L: 0.7836, NRMSE: 15.67% | Val (full) L: 0.8787, NRMSE: 16.88%
# NTK 1 Iter 3/3 - Train (full) L: 0.7794, NRMSE: 15.63% | Val (full) L: 0.8750, NRMSE: 16.84%
# NTK 1 phase (3 iterations) took 0.48 seconds.
#
# Test Set Evaluation - Loss: 0.8212, NRMSE: 15.94%
#
# --- Starting NTK 2 Phase ---
# NTK2: Computing J(X_train_ntk, Theta_0) and K_0...
# NTK2: J(X_train_ntk, Theta_0), K_0, and Error_0 computed.
# NTK 2 (Matrix Exp) Iter 15/17 - Train L: 0.7721, NRMSE: 15.56% | Val L: 0.8759, NRMSE: 16.85%
# NTK 2 (Matrix Exp) Iter 16/17 - Train L: 0.7593, NRMSE: 15.43% | Val L: 0.8683, NRMSE: 16.78%
# NTK 2 (Matrix Exp) Iter 17/17 - Train L: 0.7501, NRMSE: 15.34% | Val L: 0.8627, NRMSE: 16.73%
# NTK 2 phase (Matrix Exp, 3 iterations) took 0.38 seconds.
#
# Test Set Evaluation - Loss: 0.8240, NRMSE: 15.97%
#
# --- Starting NTK 3 Phase (Matrix Exp, T_factor=20) ---
# NTK3: Computing J(X_train_ntk, Theta_0), K_0, and Error_0...
# NTK3: J, K0, Error0 computed.
# NTK3: Solving for K0_dagger_times_Factor_times_Error (lambda_reg=0.01)...
# NTK3: Solved.
# NTK 3 (One-Shot) - Train (full) L: 0.3800, NRMSE: 10.92% | Val (full) L: 0.4863, NRMSE: 12.56%
# NTK 3 phase took 0.43 seconds.
#
# Test Set Evaluation - Loss: 0.3975, NRMSE: 11.09%
#
#
# ===== RUNNING EXPERIMENT FOR SEED 7/10 =====
#
# --- Starting SGD Phase (Monitoring for Switch using 'param_norm') ---
# SGD (Monitoring) Epoch 1 - Train L: 5.9942, NRMSE: 43.35% | Val L: 5.7229, NRMSE: 43.08% (took 0.02s)
# SGD (Monitoring) Epoch 2 - Train L: 2.3425, NRMSE: 27.10% | Val L: 2.3790, NRMSE: 27.78% | Param diff norm (k=2) = 1.555241 (took 0.02s)
# SGD (Monitoring) Epoch 3 - Train L: 1.7857, NRMSE: 23.66% | Val L: 1.8468, NRMSE: 24.47% | Param diff norm (k=2) = 0.554906 (took 0.02s)
# SGD (Monitoring) Epoch 4 - Train L: 1.5378, NRMSE: 21.96% | Val L: 1.6385, NRMSE: 23.05% | Param diff norm (k=2) = 0.301040 (took 0.02s)
# SGD (Monitoring) Epoch 5 - Train L: 1.3866, NRMSE: 20.85% | Val L: 1.4845, NRMSE: 21.94% | Param diff norm (k=2) = 0.204553 (took 0.02s)
# SGD (Monitoring) Epoch 6 - Train L: 1.2755, NRMSE: 20.00% | Val L: 1.3848, NRMSE: 21.19% | Param diff norm (k=2) = 0.172475 (took 0.02s)
# SGD (Monitoring) Epoch 7 - Train L: 1.2003, NRMSE: 19.40% | Val L: 1.3246, NRMSE: 20.73% | Param diff norm (k=2) = 0.150013 (took 0.02s)
# SGD (Monitoring) Epoch 8 - Train L: 1.1257, NRMSE: 18.79% | Val L: 1.2481, NRMSE: 20.12% | Param diff norm (k=2) = 0.131562 (took 0.02s)
# SGD (Monitoring) Epoch 9 - Train L: 1.0638, NRMSE: 18.26% | Val L: 1.1818, NRMSE: 19.58% | Param diff norm (k=2) = 0.124436 (took 0.02s)
# SGD (Monitoring) Epoch 10 - Train L: 1.0117, NRMSE: 17.81% | Val L: 1.1339, NRMSE: 19.18% | Param diff norm (k=2) = 0.112624 (took 0.02s)
# SGD (Monitoring) Epoch 11 - Train L: 0.9669, NRMSE: 17.41% | Val L: 1.0871, NRMSE: 18.78% | Param diff norm (k=2) = 0.103407 (took 0.02s)
# SGD (Monitoring) Epoch 12 - Train L: 0.9316, NRMSE: 17.09% | Val L: 1.0454, NRMSE: 18.41% | Param diff norm (k=2) = 0.101503 (took 0.02s)
# SGD (Monitoring) Epoch 13 - Train L: 0.8874, NRMSE: 16.68% | Val L: 1.0110, NRMSE: 18.11% | Param diff norm (k=2) = 0.096021 (took 0.02s)
# SGD (Monitoring) Epoch 14 - Train L: 0.8545, NRMSE: 16.37% | Val L: 0.9819, NRMSE: 17.84% | Param diff norm (k=2) = 0.092037 (took 0.02s)
# >>> Switching condition 'param_norm' met at epoch 14 over a 2-epoch window. <<<
# SGD monitoring phase (14 epochs) took 0.26 seconds.
#
# Test Set Evaluation - Loss: 0.8831, NRMSE: 16.53%
#
# --- Starting SGD (Part 2) Training Phase (Epochs 15 to 20) ---
# SGD (Part 2) Epoch 15 - Train L: 0.8229, NRMSE: 16.06% | Val L: 0.9490, NRMSE: 17.54%
# SGD (Part 2) Epoch 16 - Train L: 0.8015, NRMSE: 15.85% | Val L: 0.9382, NRMSE: 17.44%
# SGD (Part 2) Epoch 17 - Train L: 0.7703, NRMSE: 15.54% | Val L: 0.9043, NRMSE: 17.12%
# SGD (Part 2) Epoch 18 - Train L: 0.7450, NRMSE: 15.28% | Val L: 0.8745, NRMSE: 16.84%
# SGD (Part 2) Epoch 19 - Train L: 0.7227, NRMSE: 15.05% | Val L: 0.8560, NRMSE: 16.66%
# SGD (Part 2) Epoch 20 - Train L: 0.7027, NRMSE: 14.84% | Val L: 0.8323, NRMSE: 16.43%
# SGD (Part 2) phase (6 epochs) took 0.10 seconds.
#
# Test Set Evaluation - Loss: 0.7301, NRMSE: 15.03%
#
# --- Starting NTK 1 Phase ---
# NTK 1 Iter 1/3 - Train (full) L: 0.8500, NRMSE: 16.32% | Val (full) L: 0.9765, NRMSE: 17.79%
# NTK 1 Iter 2/3 - Train (full) L: 0.8458, NRMSE: 16.28% | Val (full) L: 0.9718, NRMSE: 17.75%
# NTK 1 Iter 3/3 - Train (full) L: 0.8418, NRMSE: 16.25% | Val (full) L: 0.9676, NRMSE: 17.71%
# NTK 1 phase (3 iterations) took 0.48 seconds.
#
# Test Set Evaluation - Loss: 0.8694, NRMSE: 16.40%
#
# --- Starting NTK 2 Phase ---
# NTK2: Computing J(X_train_ntk, Theta_0) and K_0...
# NTK2: J(X_train_ntk, Theta_0), K_0, and Error_0 computed.
# NTK 2 (Matrix Exp) Iter 15/17 - Train L: 0.8312, NRMSE: 16.14% | Val L: 0.9679, NRMSE: 17.72%
# NTK 2 (Matrix Exp) Iter 16/17 - Train L: 0.8197, NRMSE: 16.03% | Val L: 0.9605, NRMSE: 17.65%
# NTK 2 (Matrix Exp) Iter 17/17 - Train L: 0.8152, NRMSE: 15.99% | Val L: 0.9579, NRMSE: 17.63%
# NTK 2 phase (Matrix Exp, 3 iterations) took 0.37 seconds.
#
# Test Set Evaluation - Loss: 0.8679, NRMSE: 16.39%
#
# --- Starting NTK 3 Phase (Matrix Exp, T_factor=20) ---
# NTK3: Computing J(X_train_ntk, Theta_0), K_0, and Error_0...
# NTK3: J, K0, Error0 computed.
# NTK3: Solving for K0_dagger_times_Factor_times_Error (lambda_reg=0.01)...
# NTK3: Solved.
# NTK 3 (One-Shot) - Train (full) L: 0.3984, NRMSE: 11.18% | Val (full) L: 0.4999, NRMSE: 12.73%
# NTK 3 phase took 0.45 seconds.
#
# Test Set Evaluation - Loss: 0.4187, NRMSE: 11.38%
#
#
# ===== RUNNING EXPERIMENT FOR SEED 8/10 =====
#
# --- Starting SGD Phase (Monitoring for Switch using 'param_norm') ---
# SGD (Monitoring) Epoch 1 - Train L: 4.7053, NRMSE: 38.41% | Val L: 4.6443, NRMSE: 38.81% (took 0.02s)
# SGD (Monitoring) Epoch 2 - Train L: 2.3393, NRMSE: 27.08% | Val L: 2.3490, NRMSE: 27.60% | Param diff norm (k=2) = 1.474636 (took 0.02s)
# SGD (Monitoring) Epoch 3 - Train L: 1.7934, NRMSE: 23.71% | Val L: 1.8145, NRMSE: 24.26% | Param diff norm (k=2) = 0.479451 (took 0.02s)
# SGD (Monitoring) Epoch 4 - Train L: 1.5169, NRMSE: 21.81% | Val L: 1.5616, NRMSE: 22.50% | Param diff norm (k=2) = 0.292188 (took 0.02s)
# SGD (Monitoring) Epoch 5 - Train L: 1.3422, NRMSE: 20.51% | Val L: 1.3964, NRMSE: 21.28% | Param diff norm (k=2) = 0.230267 (took 0.02s)
# SGD (Monitoring) Epoch 6 - Train L: 1.2177, NRMSE: 19.54% | Val L: 1.2909, NRMSE: 20.46% | Param diff norm (k=2) = 0.187585 (took 0.02s)
# SGD (Monitoring) Epoch 7 - Train L: 1.1205, NRMSE: 18.74% | Val L: 1.1912, NRMSE: 19.65% | Param diff norm (k=2) = 0.156770 (took 0.02s)
# SGD (Monitoring) Epoch 8 - Train L: 1.0468, NRMSE: 18.12% | Val L: 1.1207, NRMSE: 19.06% | Param diff norm (k=2) = 0.138924 (took 0.02s)
# SGD (Monitoring) Epoch 9 - Train L: 0.9852, NRMSE: 17.58% | Val L: 1.0612, NRMSE: 18.55% | Param diff norm (k=2) = 0.124572 (took 0.02s)
# SGD (Monitoring) Epoch 10 - Train L: 0.9331, NRMSE: 17.10% | Val L: 1.0075, NRMSE: 18.08% | Param diff norm (k=2) = 0.114031 (took 0.02s)
# SGD (Monitoring) Epoch 11 - Train L: 0.8890, NRMSE: 16.70% | Val L: 0.9713, NRMSE: 17.75% | Param diff norm (k=2) = 0.105692 (took 0.02s)
# SGD (Monitoring) Epoch 12 - Train L: 0.8493, NRMSE: 16.32% | Val L: 0.9305, NRMSE: 17.37% | Param diff norm (k=2) = 0.097347 (took 0.02s)
# SGD (Monitoring) Epoch 13 - Train L: 0.8158, NRMSE: 15.99% | Val L: 0.8954, NRMSE: 17.04% | Param diff norm (k=2) = 0.090697 (took 0.02s)
# >>> Switching condition 'param_norm' met at epoch 13 over a 2-epoch window. <<<
# SGD monitoring phase (13 epochs) took 0.25 seconds.
#
# Test Set Evaluation - Loss: 0.8291, NRMSE: 16.02%
#
# --- Starting SGD (Part 2) Training Phase (Epochs 14 to 20) ---
# SGD (Part 2) Epoch 14 - Train L: 0.7907, NRMSE: 15.74% | Val L: 0.8653, NRMSE: 16.75%
# SGD (Part 2) Epoch 15 - Train L: 0.7567, NRMSE: 15.40% | Val L: 0.8357, NRMSE: 16.46%
# SGD (Part 2) Epoch 16 - Train L: 0.7323, NRMSE: 15.15% | Val L: 0.8225, NRMSE: 16.33%
# SGD (Part 2) Epoch 17 - Train L: 0.7089, NRMSE: 14.91% | Val L: 0.7894, NRMSE: 16.00%
# SGD (Part 2) Epoch 18 - Train L: 0.6856, NRMSE: 14.66% | Val L: 0.7721, NRMSE: 15.82%
# SGD (Part 2) Epoch 19 - Train L: 0.6672, NRMSE: 14.46% | Val L: 0.7621, NRMSE: 15.72%
# SGD (Part 2) Epoch 20 - Train L: 0.6522, NRMSE: 14.30% | Val L: 0.7533, NRMSE: 15.63%
# SGD (Part 2) phase (7 epochs) took 0.12 seconds.
#
# Test Set Evaluation - Loss: 0.6731, NRMSE: 14.43%
#
# --- Starting NTK 1 Phase ---
# NTK 1 Iter 1/4 - Train (full) L: 0.8113, NRMSE: 15.95% | Val (full) L: 0.8920, NRMSE: 17.01%
# NTK 1 Iter 2/4 - Train (full) L: 0.8071, NRMSE: 15.91% | Val (full) L: 0.8885, NRMSE: 16.97%
# NTK 1 Iter 3/4 - Train (full) L: 0.8030, NRMSE: 15.87% | Val (full) L: 0.8849, NRMSE: 16.94%
# NTK 1 Iter 4/4 - Train (full) L: 0.7990, NRMSE: 15.83% | Val (full) L: 0.8812, NRMSE: 16.90%
# NTK 1 phase (4 iterations) took 0.63 seconds.
#
# Test Set Evaluation - Loss: 0.8138, NRMSE: 15.87%
#
# --- Starting NTK 2 Phase ---
# NTK2: Computing J(X_train_ntk, Theta_0) and K_0...
# NTK2: J(X_train_ntk, Theta_0), K_0, and Error_0 computed.
# NTK 2 (Matrix Exp) Iter 14/17 - Train L: 0.7888, NRMSE: 15.73% | Val L: 0.8783, NRMSE: 16.88%
# NTK 2 (Matrix Exp) Iter 15/17 - Train L: 0.7724, NRMSE: 15.56% | Val L: 0.8672, NRMSE: 16.77%
# NTK 2 (Matrix Exp) Iter 16/17 - Train L: 0.7639, NRMSE: 15.48% | Val L: 0.8614, NRMSE: 16.71%
# NTK 2 (Matrix Exp) Iter 17/17 - Train L: 0.7618, NRMSE: 15.45% | Val L: 0.8594, NRMSE: 16.69%
# NTK 2 phase (Matrix Exp, 4 iterations) took 0.50 seconds.
#
# Test Set Evaluation - Loss: 0.8028, NRMSE: 15.76%
#
# --- Starting NTK 3 Phase (Matrix Exp, T_factor=20) ---
# NTK3: Computing J(X_train_ntk, Theta_0), K_0, and Error_0...
# NTK3: J, K0, Error0 computed.
# NTK3: Solving for K0_dagger_times_Factor_times_Error (lambda_reg=0.01)...
# NTK3: Solved.
# NTK 3 (One-Shot) - Train (full) L: 0.4408, NRMSE: 11.76% | Val (full) L: 0.5665, NRMSE: 13.55%
# NTK 3 phase took 0.43 seconds.
#
# Test Set Evaluation - Loss: 0.4731, NRMSE: 12.10%
#
#
# ===== RUNNING EXPERIMENT FOR SEED 9/10 =====
#
# --- Starting SGD Phase (Monitoring for Switch using 'param_norm') ---
# SGD (Monitoring) Epoch 1 - Train L: 5.1974, NRMSE: 40.37% | Val L: 5.1846, NRMSE: 41.00% (took 0.02s)
# SGD (Monitoring) Epoch 2 - Train L: 2.4907, NRMSE: 27.95% | Val L: 2.5898, NRMSE: 28.98% | Param diff norm (k=2) = 1.476954 (took 0.02s)
# SGD (Monitoring) Epoch 3 - Train L: 1.8740, NRMSE: 24.24% | Val L: 2.0204, NRMSE: 25.60% | Param diff norm (k=2) = 0.513404 (took 0.02s)
# SGD (Monitoring) Epoch 4 - Train L: 1.5758, NRMSE: 22.23% | Val L: 1.7525, NRMSE: 23.84% | Param diff norm (k=2) = 0.313098 (took 0.02s)
# SGD (Monitoring) Epoch 5 - Train L: 1.3854, NRMSE: 20.84% | Val L: 1.5840, NRMSE: 22.66% | Param diff norm (k=2) = 0.235854 (took 0.02s)
# SGD (Monitoring) Epoch 6 - Train L: 1.2610, NRMSE: 19.88% | Val L: 1.4632, NRMSE: 21.78% | Param diff norm (k=2) = 0.190528 (took 0.02s)
# SGD (Monitoring) Epoch 7 - Train L: 1.1554, NRMSE: 19.03% | Val L: 1.3682, NRMSE: 21.06% | Param diff norm (k=2) = 0.161706 (took 0.02s)
# SGD (Monitoring) Epoch 8 - Train L: 1.0796, NRMSE: 18.40% | Val L: 1.3016, NRMSE: 20.54% | Param diff norm (k=2) = 0.145270 (took 0.02s)
# SGD (Monitoring) Epoch 9 - Train L: 1.0117, NRMSE: 17.81% | Val L: 1.2262, NRMSE: 19.94% | Param diff norm (k=2) = 0.128021 (took 0.02s)
# SGD (Monitoring) Epoch 10 - Train L: 0.9567, NRMSE: 17.32% | Val L: 1.1793, NRMSE: 19.56% | Param diff norm (k=2) = 0.116557 (took 0.02s)
# SGD (Monitoring) Epoch 11 - Train L: 0.9056, NRMSE: 16.85% | Val L: 1.1258, NRMSE: 19.11% | Param diff norm (k=2) = 0.110954 (took 0.02s)
# SGD (Monitoring) Epoch 12 - Train L: 0.8645, NRMSE: 16.46% | Val L: 1.0871, NRMSE: 18.78% | Param diff norm (k=2) = 0.103790 (took 0.02s)
# SGD (Monitoring) Epoch 13 - Train L: 0.8276, NRMSE: 16.11% | Val L: 1.0447, NRMSE: 18.41% | Param diff norm (k=2) = 0.095023 (took 0.02s)
# SGD (Monitoring) Epoch 14 - Train L: 0.7993, NRMSE: 15.83% | Val L: 1.0248, NRMSE: 18.23% | Param diff norm (k=2) = 0.089547 (took 0.02s)
# >>> Switching condition 'param_norm' met at epoch 14 over a 2-epoch window. <<<
# SGD monitoring phase (14 epochs) took 0.26 seconds.
#
# Test Set Evaluation - Loss: 0.8589, NRMSE: 16.30%
#
# --- Starting SGD (Part 2) Training Phase (Epochs 15 to 20) ---
# SGD (Part 2) Epoch 15 - Train L: 0.7631, NRMSE: 15.47% | Val L: 0.9739, NRMSE: 17.77%
# SGD (Part 2) Epoch 16 - Train L: 0.7378, NRMSE: 15.21% | Val L: 0.9548, NRMSE: 17.60%
# SGD (Part 2) Epoch 17 - Train L: 0.7222, NRMSE: 15.05% | Val L: 0.9444, NRMSE: 17.50%
# SGD (Part 2) Epoch 18 - Train L: 0.6867, NRMSE: 14.67% | Val L: 0.8910, NRMSE: 17.00%
# SGD (Part 2) Epoch 19 - Train L: 0.6648, NRMSE: 14.44% | Val L: 0.8677, NRMSE: 16.77%
# SGD (Part 2) Epoch 20 - Train L: 0.6465, NRMSE: 14.24% | Val L: 0.8428, NRMSE: 16.53%
# SGD (Part 2) phase (6 epochs) took 0.10 seconds.
#
# Test Set Evaluation - Loss: 0.6884, NRMSE: 14.60%
#
# --- Starting NTK 1 Phase ---
# NTK 1 Iter 1/3 - Train (full) L: 0.7912, NRMSE: 15.75% | Val (full) L: 1.0126, NRMSE: 18.12%
# NTK 1 Iter 2/3 - Train (full) L: 0.7859, NRMSE: 15.70% | Val (full) L: 1.0046, NRMSE: 18.05%
# NTK 1 Iter 3/3 - Train (full) L: 0.7815, NRMSE: 15.65% | Val (full) L: 0.9985, NRMSE: 17.99%
# NTK 1 phase (3 iterations) took 0.48 seconds.
#
# Test Set Evaluation - Loss: 0.8363, NRMSE: 16.09%
#
# --- Starting NTK 2 Phase ---
# NTK2: Computing J(X_train_ntk, Theta_0) and K_0...
# NTK2: J(X_train_ntk, Theta_0), K_0, and Error_0 computed.
# NTK 2 (Matrix Exp) Iter 15/17 - Train L: 0.7791, NRMSE: 15.63% | Val L: 1.0166, NRMSE: 18.16%
# NTK 2 (Matrix Exp) Iter 16/17 - Train L: 0.7683, NRMSE: 15.52% | Val L: 1.0115, NRMSE: 18.11%
# NTK 2 (Matrix Exp) Iter 17/17 - Train L: 0.7647, NRMSE: 15.48% | Val L: 1.0099, NRMSE: 18.10%
# NTK 2 phase (Matrix Exp, 3 iterations) took 0.39 seconds.
#
# Test Set Evaluation - Loss: 0.8427, NRMSE: 16.15%
#
# --- Starting NTK 3 Phase (Matrix Exp, T_factor=20) ---
# NTK3: Computing J(X_train_ntk, Theta_0), K_0, and Error_0...
# NTK3: J, K0, Error0 computed.
# NTK3: Solving for K0_dagger_times_Factor_times_Error (lambda_reg=0.01)...
# NTK3: Solved.
# NTK 3 (One-Shot) - Train (full) L: 0.4600, NRMSE: 12.01% | Val (full) L: 0.6436, NRMSE: 14.45%
# NTK 3 phase took 0.44 seconds.
#
# Test Set Evaluation - Loss: 0.4859, NRMSE: 12.26%
#
#
# ===== RUNNING EXPERIMENT FOR SEED 10/10 =====
#
# --- Starting SGD Phase (Monitoring for Switch using 'param_norm') ---
# SGD (Monitoring) Epoch 1 - Train L: 6.0979, NRMSE: 43.72% | Val L: 5.8536, NRMSE: 43.57% (took 0.02s)
# SGD (Monitoring) Epoch 2 - Train L: 2.4385, NRMSE: 27.65% | Val L: 2.4270, NRMSE: 28.05% | Param diff norm (k=2) = 1.601542 (took 0.02s)
# SGD (Monitoring) Epoch 3 - Train L: 1.8799, NRMSE: 24.28% | Val L: 1.9355, NRMSE: 25.05% | Param diff norm (k=2) = 0.556799 (took 0.02s)
# SGD (Monitoring) Epoch 4 - Train L: 1.6123, NRMSE: 22.48% | Val L: 1.7028, NRMSE: 23.50% | Param diff norm (k=2) = 0.304313 (took 0.02s)
# SGD (Monitoring) Epoch 5 - Train L: 1.4413, NRMSE: 21.26% | Val L: 1.5512, NRMSE: 22.43% | Param diff norm (k=2) = 0.224337 (took 0.02s)
# SGD (Monitoring) Epoch 6 - Train L: 1.3140, NRMSE: 20.30% | Val L: 1.4429, NRMSE: 21.63% | Param diff norm (k=2) = 0.179749 (took 0.02s)
# SGD (Monitoring) Epoch 7 - Train L: 1.2138, NRMSE: 19.51% | Val L: 1.3520, NRMSE: 20.94% | Param diff norm (k=2) = 0.163076 (took 0.02s)
# SGD (Monitoring) Epoch 8 - Train L: 1.1435, NRMSE: 18.93% | Val L: 1.2849, NRMSE: 20.41% | Param diff norm (k=2) = 0.143973 (took 0.02s)
# SGD (Monitoring) Epoch 9 - Train L: 1.0770, NRMSE: 18.38% | Val L: 1.2281, NRMSE: 19.96% | Param diff norm (k=2) = 0.127321 (took 0.02s)
# SGD (Monitoring) Epoch 10 - Train L: 1.0266, NRMSE: 17.94% | Val L: 1.1725, NRMSE: 19.50% | Param diff norm (k=2) = 0.117786 (took 0.02s)
# SGD (Monitoring) Epoch 11 - Train L: 0.9724, NRMSE: 17.46% | Val L: 1.1302, NRMSE: 19.14% | Param diff norm (k=2) = 0.108501 (took 0.02s)
# SGD (Monitoring) Epoch 12 - Train L: 0.9295, NRMSE: 17.07% | Val L: 1.0878, NRMSE: 18.78% | Param diff norm (k=2) = 0.103326 (took 0.02s)
# SGD (Monitoring) Epoch 13 - Train L: 0.8941, NRMSE: 16.74% | Val L: 1.0589, NRMSE: 18.53% | Param diff norm (k=2) = 0.097704 (took 0.02s)
# SGD (Monitoring) Epoch 14 - Train L: 0.8535, NRMSE: 16.36% | Val L: 1.0153, NRMSE: 18.15% | Param diff norm (k=2) = 0.092909 (took 0.02s)
# >>> Switching condition 'param_norm' met at epoch 14 over a 2-epoch window. <<<
# SGD monitoring phase (14 epochs) took 0.26 seconds.
#
# Test Set Evaluation - Loss: 0.8768, NRMSE: 16.47%
#
# --- Starting SGD (Part 2) Training Phase (Epochs 15 to 20) ---
# SGD (Part 2) Epoch 15 - Train L: 0.8222, NRMSE: 16.06% | Val L: 0.9886, NRMSE: 17.90%
# SGD (Part 2) Epoch 16 - Train L: 0.7903, NRMSE: 15.74% | Val L: 0.9558, NRMSE: 17.61%
# SGD (Part 2) Epoch 17 - Train L: 0.7651, NRMSE: 15.49% | Val L: 0.9220, NRMSE: 17.29%
# SGD (Part 2) Epoch 18 - Train L: 0.7355, NRMSE: 15.19% | Val L: 0.8982, NRMSE: 17.07%
# SGD (Part 2) Epoch 19 - Train L: 0.7158, NRMSE: 14.98% | Val L: 0.8929, NRMSE: 17.02%
# SGD (Part 2) Epoch 20 - Train L: 0.6923, NRMSE: 14.73% | Val L: 0.8520, NRMSE: 16.62%
# SGD (Part 2) phase (6 epochs) took 0.10 seconds.
#
# Test Set Evaluation - Loss: 0.7188, NRMSE: 14.91%
#
# --- Starting NTK 1 Phase ---
# NTK 1 Iter 1/3 - Train (full) L: 0.8488, NRMSE: 16.31% | Val (full) L: 1.0100, NRMSE: 18.10%
# NTK 1 Iter 2/3 - Train (full) L: 0.8444, NRMSE: 16.27% | Val (full) L: 1.0053, NRMSE: 18.06%
# NTK 1 Iter 3/3 - Train (full) L: 0.8401, NRMSE: 16.23% | Val (full) L: 1.0010, NRMSE: 18.02%
# NTK 1 phase (3 iterations) took 0.48 seconds.
#
# Test Set Evaluation - Loss: 0.8629, NRMSE: 16.34%
#
# --- Starting NTK 2 Phase ---
# NTK2: Computing J(X_train_ntk, Theta_0) and K_0...
# NTK2: J(X_train_ntk, Theta_0), K_0, and Error_0 computed.
# NTK 2 (Matrix Exp) Iter 15/17 - Train L: 0.8294, NRMSE: 16.13% | Val L: 0.9977, NRMSE: 17.99%
# NTK 2 (Matrix Exp) Iter 16/17 - Train L: 0.8175, NRMSE: 16.01% | Val L: 0.9865, NRMSE: 17.89%
# NTK 2 (Matrix Exp) Iter 17/17 - Train L: 0.8123, NRMSE: 15.96% | Val L: 0.9789, NRMSE: 17.82%
# NTK 2 phase (Matrix Exp, 3 iterations) took 0.38 seconds.
#
# Test Set Evaluation - Loss: 0.8544, NRMSE: 16.26%
#
# --- Starting NTK 3 Phase (Matrix Exp, T_factor=20) ---
# NTK3: Computing J(X_train_ntk, Theta_0), K_0, and Error_0...
# NTK3: J, K0, Error0 computed.
# NTK3: Solving for K0_dagger_times_Factor_times_Error (lambda_reg=0.01)...
# NTK3: Solved.
# NTK 3 (One-Shot) - Train (full) L: 0.4170, NRMSE: 11.43% | Val (full) L: 0.5486, NRMSE: 13.34%
# NTK 3 phase took 0.45 seconds.
#
# Test Set Evaluation - Loss: 0.4490, NRMSE: 11.79%

# %% [markdown]
# Average results:

# %%
avg_histories = {}
avg_histories['SGD_Part1'] = aggregate_histories(all_runs_histories['SGD_Part1'], metric_keys=['val_loss', 'val_nrmse'])
avg_histories['SGD_Part2'] = aggregate_histories(all_runs_histories['SGD_Part2'], metric_keys=['train_loss', 'train_nrmse', 'val_loss', 'val_nrmse'])
avg_histories['NTK1_from_Switch'] = aggregate_histories(all_runs_histories['NTK1_from_Switch'], metric_keys=['train_loss', 'train_nrmse', 'val_loss', 'val_nrmse'])
avg_histories['NTK2_from_Switch'] = aggregate_histories(all_runs_histories['NTK2_from_Switch'], metric_keys=['train_loss', 'train_nrmse', 'val_loss', 'val_nrmse'])

ntk3_final_train_losses = [h['train_loss'][0] for h in all_runs_histories['NTK3_from_Switch'] if h['train_loss']]
ntk3_final_val_losses   = [h['val_loss'][0] for h in all_runs_histories['NTK3_from_Switch'] if h['val_loss']]
ntk3_final_train_nrmses = [h['train_nrmse'][0] for h in all_runs_histories['NTK3_from_Switch'] if h['train_nrmse']]
ntk3_final_val_nrmses   = [h['val_nrmse'][0] for h in all_runs_histories['NTK3_from_Switch'] if h['val_nrmse']]

avg_histories['NTK3_from_Switch_Aggregated'] = {
    'train_loss': aggregate_scalar_metrics(ntk3_final_train_losses),
    'val_loss':   aggregate_scalar_metrics(ntk3_final_val_losses),
    'train_nrmse': aggregate_scalar_metrics(ntk3_final_train_nrmses),
    'val_nrmse':  aggregate_scalar_metrics(ntk3_final_val_nrmses)
}

avg_switch_epoch = np.mean(all_runs_switch_epochs)

avg_times = {phase: np.mean(times) for phase, times in all_runs_times.items() if times}
avg_test_metrics = {}
for phase, metrics_list in all_runs_test_metrics.items():
    if metrics_list:
        avg_test_metrics[phase] = {
            'loss_mean': np.nanmean([m.get('loss', np.nan) for m in metrics_list]),
            'loss_std':  np.nanstd([m.get('loss', np.nan) for m in metrics_list]),
            'nrmse_mean': np.nanmean([m.get('nrmse', np.nan) for m in metrics_list]),
            'nrmse_std':  np.nanstd([m.get('nrmse', np.nan) for m in metrics_list])
        }

# %% [markdown]
# Plot the results:

# %%
# --- DYNAMIC FILENAME GENERATION FOR MAIN EXPERIMENT ---
dataset_prefix = "wine_tr"
network_width = layer_dims[1]
metric_char = 'n' if switch_config['method'] == 'ntk_norm' else 'p'
threshold = switch_config.get(f"{switch_config['method']}_threshold", 0.0) or 0.0
lr_val = lr_sgd_config
filename_template = f"{dataset_prefix}_{{metric_type}}_{metric_char}_{network_width}_{lr_val}_{threshold:.4f}.png"

# --- PLOTTING SETUP ---
# Define font sizes for better readability in a report
TITLE_FONT = 18
LABEL_FONT = 30
LEGEND_FONT = 18
TICK_FONT = 12

# --- PLOT 1: LOSS TRAJECTORIES ---
fig1, ax1 = plt.subplots(1, 1, figsize=(15, 8))

# --- Create full SGD trajectories for each run, then aggregate. ---
full_sgd_histories = []
metric_keys_to_agg = ['train_loss', 'val_loss', 'train_nrmse', 'val_nrmse']
for h1, h2 in zip(all_runs_histories['SGD_Part1'], all_runs_histories['SGD_Part2']):
    full_sgd_histories.append({
        'train_loss': h1.get('train_loss', []) + h2.get('train_loss', []),
        'val_loss': h1.get('val_loss', []) + h2.get('val_loss', []),
        'train_nrmse': h1.get('train_nrmse', []) + h2.get('train_nrmse', []),
        'val_nrmse': h1.get('val_nrmse', []) + h2.get('val_nrmse', [])
    })
avg_sgd_full = aggregate_histories(full_sgd_histories, metric_keys=metric_keys_to_agg)

# Plot averaged full SGD trajectory (1-based epochs)
num_full_epochs = len(avg_sgd_full['val_loss']['mean'])
epochs_x_full_sgd = np.arange(1, num_full_epochs + 1)

if epochs_x_full_sgd.size > 0:
    ax1.plot(epochs_x_full_sgd, avg_sgd_full['train_loss']['mean'], label='Avg. SGD Train', marker='o', linestyle='-', color='royalblue', alpha=0.9, zorder=10)
    ax1.plot(epochs_x_full_sgd, avg_sgd_full['val_loss']['mean'], label='Avg. SGD Val', marker='x', linestyle='--', color='skyblue', alpha=0.9, zorder=10)
    ax1.fill_between(epochs_x_full_sgd,
                     np.array(avg_sgd_full['val_loss']['mean']) - np.array(avg_sgd_full['val_loss']['std']),
                     np.array(avg_sgd_full['val_loss']['mean']) + np.array(avg_sgd_full['val_loss']['std']),
                     color='skyblue', alpha=0.2, zorder=5)

# Plot Individual NTK Trajectories
for i in range(num_seeds):
    switch_epoch = all_runs_switch_epochs[i]
    start_point_index = switch_epoch - 1

    if start_point_index < len(all_runs_histories['SGD_Part1'][i]['val_loss']):
        start_tl = all_runs_histories['SGD_Part1'][i]['train_loss'][start_point_index]
        start_vl = all_runs_histories['SGD_Part1'][i]['val_loss'][start_point_index]

        for ntk_key, color, marker_style in [('NTK1_from_Switch', 'green', '^'), ('NTK2_from_Switch', 'purple', 's')]:
            if i < len(all_runs_histories[ntk_key]):
                ntk_hist = all_runs_histories[ntk_key][i]
                ntk_len = len(ntk_hist['val_loss'])
                if ntk_len > 0:
                    epochs_x_ntk = np.arange(switch_epoch + 1, switch_epoch + 1 + ntk_len)
                    x_branch = np.insert(epochs_x_ntk, 0, switch_epoch)
                    tl_branch = [start_tl] + ntk_hist['train_loss']
                    vl_branch = [start_vl] + ntk_hist['val_loss']
                    label_prefix = ntk_key.split('_')[0]
                    ax1.plot(x_branch, tl_branch, marker=marker_style, linestyle='-', color=color, alpha=0.2, label=f'{label_prefix} Train (Seed)' if i == 0 else None)
                    ax1.plot(x_branch, vl_branch, marker=marker_style, linestyle=':', color=color, alpha=0.2, label=f'{label_prefix} Val (Seed)' if i == 0 else None, mfc='none')

# Plot NTK3 (One-Shot)
avg_ntk3_loss = avg_histories['NTK3_from_Switch_Aggregated']['val_loss']
ax1.errorbar(epochs_sgd_total_config, avg_ntk3_loss['mean'], yerr=avg_ntk3_loss['std'], fmt='P', markersize=15, color='orange', label='Avg. NTK3 Val', zorder=11, capsize=5)

# Plot Average Switch Point
avg_switch_epoch_plot = np.mean(all_runs_switch_epochs)
ax1.axvline(x=avg_switch_epoch_plot, color='dimgray', linestyle=':', linewidth=3, label=f'Avg. Switch (Ep {avg_switch_epoch_plot:.1f})')

# Final Touches for Loss Plot
ax1.set_ylabel("MSE Loss", fontsize=LABEL_FONT)
ax1.set_xlabel("Epochs", fontsize=LABEL_FONT)
ax1.legend(fontsize=LEGEND_FONT, loc='best')
ax1.grid(True, which='both', linestyle='--')
ax1.tick_params(axis='both', which='major', labelsize=TICK_FONT)
ax1.set_xlim(left=0.5, right=epochs_sgd_total_config + 0.5)
fig1.tight_layout()
loss_filename = filename_template.format(metric_type='loss')
plt.savefig(loss_filename)
print(f"\nLoss plot saved as {loss_filename}")
plt.show()


# --- PLOT 2: NRMSE TRAJECTORIES ---
fig2, ax2 = plt.subplots(1, 1, figsize=(15, 8))

# Plot averaged full SGD trajectory for NRMSE
if epochs_x_full_sgd.size > 0:
    ax2.plot(epochs_x_full_sgd, np.array(avg_sgd_full['train_nrmse']['mean'])*100, label='Avg. SGD Train', marker='o', linestyle='-', color='royalblue', alpha=0.9, zorder=10)
    ax2.plot(epochs_x_full_sgd, np.array(avg_sgd_full['val_nrmse']['mean'])*100, label='Avg. SGD Val', marker='x', linestyle='--', color='skyblue', alpha=0.9, zorder=10)
    ax2.fill_between(epochs_x_full_sgd,
                     (np.array(avg_sgd_full['val_nrmse']['mean']) - np.array(avg_sgd_full['val_nrmse']['std']))*100,
                     (np.array(avg_sgd_full['val_nrmse']['mean']) + np.array(avg_sgd_full['val_nrmse']['std']))*100,
                     color='skyblue', alpha=0.2, zorder=5)

# Plot Individual NTK Trajectories for NRMSE
for i in range(num_seeds):
    switch_epoch = all_runs_switch_epochs[i]
    start_point_index = switch_epoch - 1

    if start_point_index < len(all_runs_histories['SGD_Part1'][i]['val_nrmse']):
        start_tnrmse = all_runs_histories['SGD_Part1'][i]['train_nrmse'][start_point_index]
        start_vnrmse = all_runs_histories['SGD_Part1'][i]['val_nrmse'][start_point_index]

        for ntk_key, color, marker_style in [('NTK1_from_Switch', 'green', '^'), ('NTK2_from_Switch', 'purple', 's')]:
            if i < len(all_runs_histories[ntk_key]):
                ntk_hist = all_runs_histories[ntk_key][i]
                ntk_len = len(ntk_hist['val_nrmse'])
                if ntk_len > 0:
                    epochs_x_ntk = np.arange(switch_epoch + 1, switch_epoch + 1 + ntk_len)
                    x_branch = np.insert(epochs_x_ntk, 0, switch_epoch)
                    tnrmse_branch = np.array([start_tnrmse] + ntk_hist['train_nrmse']) * 100
                    vnrmse_branch = np.array([start_vnrmse] + ntk_hist['val_nrmse']) * 100
                    label_prefix = ntk_key.split('_')[0]
                    ax2.plot(x_branch, tnrmse_branch, marker=marker_style, linestyle='-', color=color, alpha=0.2, label=f'{label_prefix} Train (Seed)' if i == 0 else None)
                    ax2.plot(x_branch, vnrmse_branch, marker=marker_style, linestyle=':', color=color, alpha=0.2, label=f'{label_prefix} Val (Seed)' if i == 0 else None, mfc='none')

# Plot NTK3 (One-Shot) for NRMSE
avg_ntk3_nrmse = avg_histories['NTK3_from_Switch_Aggregated']['val_nrmse']
ax2.errorbar(epochs_sgd_total_config, avg_ntk3_nrmse['mean']*100, yerr=avg_ntk3_nrmse['std']*100, fmt='P', markersize=15, color='orange', label='Avg. NTK3 Val', zorder=11, capsize=5)

# Plot Average Switch Point
ax2.axvline(x=avg_switch_epoch_plot, color='dimgray', linestyle=':', linewidth=3, label=f'Avg. Switch (Ep {avg_switch_epoch_plot:.1f})')

# Final Touches for NRMSE Plot
ax2.set_ylabel("Normalized RMSE (%)", fontsize=LABEL_FONT)
ax2.set_xlabel("Epochs", fontsize=LABEL_FONT)
ax2.legend(fontsize=LEGEND_FONT, loc='best')
ax2.grid(True, which='both', linestyle='--')
ax2.tick_params(axis='both', which='major', labelsize=TICK_FONT)
ax2.set_xlim(left=0.5, right=epochs_sgd_total_config + 0.5)
fig2.tight_layout()
nrmse_filename = filename_template.format(metric_type='nrmse')
plt.savefig(nrmse_filename)
print(f"NRMSE plot saved as {nrmse_filename}")
plt.show()
# Out:
# Loss plot saved as wine_tr_loss_p_100_0.007_0.0945.png
# NRMSE plot saved as wine_tr_nrmse_p_100_0.007_0.0945.png

# %% [markdown]
# Summarize the results:

# %%
print("\\n--- Averaged Final Test Metrics & Runtimes (across {} seeds) ---".format(num_seeds))
print(f"Switch Method: {switch_config['method']}")
print(f"Average Switch Epoch: {avg_switch_epoch:.2f} ± {np.std(all_runs_switch_epochs):.2f}")
print(f"\\nSGD Part 1 (Monitoring Phase): Avg. Time: {avg_times.get('SGD (Part 1)',0.0):.2f}s")
if 'Params_At_Switch' in avg_test_metrics:
    m = avg_test_metrics['Params_At_Switch']
    print(f"  Params at Switch Point Test: Avg. Loss: {m['loss_mean']:.4f} ± {m['loss_std']:.4f}, Avg. NRMSE: {m['nrmse_mean']*100:.2f}% ± {m['nrmse_std']*100:.2f}%")

print(f"SGD Part 2 (Post-Switch Phase): Avg. Time: {avg_times.get('SGD (Part 2)',0.0):.2f}s")

if 'SGD_Full_Run' in avg_test_metrics:
    m = avg_test_metrics['SGD_Full_Run']
    total_avg_sgd_time = avg_times.get('SGD (Part 1)', 0.0) + avg_times.get('SGD (Part 2)', 0.0)
    print(f"SGD Full Run ({epochs_sgd_total_config} total epochs): Avg. Total Time: {total_avg_sgd_time:.2f}s")
    print(f"  Test: Avg. Loss: {m['loss_mean']:.4f} ± {m['loss_std']:.4f}, Avg. NRMSE: {m['nrmse_mean']*100:.2f}% ± {m['nrmse_std']*100:.2f}%")

print("") # Add a blank line for readability

for phase_key_suffix in ['NTK1', 'NTK2', 'NTK3']:
    full_phase_key = f'{phase_key_suffix}_from_Switch'
    if full_phase_key in avg_test_metrics:
        m = avg_test_metrics[full_phase_key]
        avg_time = avg_times.get(phase_key_suffix, 0.0)
        print(f"Phase: {phase_key_suffix:<5} (from switch) | Avg. Test Loss: {m['loss_mean']:.4f} ± {m['loss_std']:.4f}, Avg. Test NRMSE: {m['nrmse_mean']*100:.2f}% ± {m['nrmse_std']*100:.2f}% | Avg. Time: {avg_time:.2f}s")
# Out:
# \n--- Averaged Final Test Metrics & Runtimes (across 10 seeds) ---
# Switch Method: param_norm
# Average Switch Epoch: 13.40 ± 0.66
# \nSGD Part 1 (Monitoring Phase): Avg. Time: 0.26s
#   Params at Switch Point Test: Avg. Loss: 0.8515 ± 0.0246, Avg. NRMSE: 16.23% ± 0.24%
# SGD Part 2 (Post-Switch Phase): Avg. Time: 0.11s
# SGD Full Run (20 total epochs): Avg. Total Time: 0.37s
#   Test: Avg. Loss: 0.6893 ± 0.0280, Avg. NRMSE: 14.60% ± 0.30%
#
# Phase: NTK1  (from switch) | Avg. Test Loss: 0.8350 ± 0.0251, Avg. Test NRMSE: 16.07% ± 0.24% | Avg. Time: 0.55s
# Phase: NTK2  (from switch) | Avg. Test Loss: 0.8389 ± 0.0304, Avg. Test NRMSE: 16.11% ± 0.29% | Avg. Time: 0.46s
# Phase: NTK3  (from switch) | Avg. Test Loss: 0.4491 ± 0.0361, Avg. Test NRMSE: 11.78% ± 0.47% | Avg. Time: 0.44s
